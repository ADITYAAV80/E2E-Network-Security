# %%
import os
os.chdir("../")

# %%
import sys
import json
import certifi
from dotenv import load_dotenv
import pandas as pd
import numpy as np
import pymongo
from src.NetworkSecurity.exception.exception import NetworkSecurityException
from src.NetworkSecurity.logging.logger import logger

load_dotenv()
MONGO_DB_URL=os.getenv("MONGO_DB_URL")

class NetWorkDataExtract():

    def __init__(self):
        pass

    def cv_to_json_converter(self,file_path):

        try:
            df = pd.read_csv(file_path)
            df.drop(columns=["id"],inplace=True)
            ## converts to json
            json_str = json.loads(df.T.to_json()) #{0:row1,1:row2,...}
            records = list(json_str.values()) # [{row1},{row2}...]
        except Exception as e:
            raise NetworkSecurityException(e,sys)
        
        return records
    
    def insert_data_mongodb(self,records,database,collection):

        try:
            self.database = database
            self.collection = collection
            self.records = records
            self.mongo_client = pymongo.MongoClient(MONGO_DB_URL, tlsCAFile=certifi.where())

            self.database = self.database[self.collection]
            self.collection.insert_many(self.records)

            #logger.info()
            return len(self.records)
        except Exception as e:
            raise NetworkSecurityException(e,sys)

nde = NetWorkDataExtract()
ret = nde.cv_to_json_converter("/home/aditya/network_security/NetworkSecurityData/PriorETL/data.csv")

# %%
# Out:
# [{'NumDots': 3.0,
#   'SubdomainLevel': 1.0,
#   'PathLevel': 5.0,
#   'UrlLength': 72.0,
#   'NumDash': 0.0,
#   'NumDashInHostname': 0.0,
#   'AtSymbol': 0.0,
#   'TildeSymbol': 0.0,
#   'NumUnderscore': 0.0,
#   'NumPercent': 0.0,
#   'NumQueryComponents': 0.0,
#   'NumAmpersand': 0.0,
#   'NumHash': 0.0,
#   'NumNumericChars': 0.0,
#   'NoHttps': 1.0,
#   'RandomString': 0.0,
#   'IpAddress': 0.0,
#   'DomainInSubdomains': 0.0,
#   'DomainInPaths': 0.0,
#   'HttpsInHostname': 0.0,
#   'HostnameLength': 21.0,
#   'PathLength': 44.0,
#   'QueryLength': 0.0,
#   'DoubleSlashInPath': 0.0,
#   'NumSensitiveWords': 0.0,
#   'EmbeddedBrandName': 0.0,
#   'PctExtHyperlinks': 0.0,
#   'PctExtResourceUrls': 0.25,
#   'ExtFavicon': 1.0,
#   'InsecureForms': 1.0,
#   'RelativeFormAction': 0.0,
#   'ExtFormAction': 0.0,
#   'AbnormalFormAction': 0.0,
#   'PctNullSelfRedirectHyperlinks': 0.0,
#   'FrequentDomainNameMismatch': 0.0,
#   'FakeLinkInStatusBar': 0.0,
#   'RightClickDisabled': 0.0,
#   'PopUpWindow': 0.0,
#   'SubmitInfoToEmail': 0.0,
#   'IframeOrFrame': 0.0,
#   'MissingTitle': 0.0,
#   'ImagesOnlyInForm': 1.0,
#   'SubdomainLevelRT': 1.0,
#   'UrlLengthRT': 0.0,
#   'PctExtResourceUrlsRT': 1.0,
#   'AbnormalExtFormActionR': 1.0,
#   'ExtMetaScriptLinkRT': -1.0,
#   'PctExtNullSelfRedirectHyperlinksRT': 1.0,
#   'CLASS_LABEL': 1.0},
#  {'NumDots': 3.0,
#   'SubdomainLevel': 1.0,
#   'PathLevel': 3.0,
#   'UrlLength': 144.0,
#   'NumDash': 0.0,
#   'NumDashInHostname': 0.0,
#   'AtSymbol': 0.0,
#   'TildeSymbol': 0.0,
#   'NumUnderscore': 2.0,
#   'NumPercent': 0.0,
#   'NumQueryComponents': 2.0,
#   'NumAmpersand': 1.0,
#   'NumHash': 0.0,
#   'NumNumericChars': 41.0,
#   'NoHttps': 1.0,
#   'RandomString': 0.0,
#   'IpAddress': 0.0,
#   'DomainInSubdomains': 0.0,
#   'DomainInPaths': 0.0,
#   'HttpsInHostname': 0.0,
#   'HostnameLength': 17.0,
#   'PathLength': 16.0,
#   'QueryLength': 103.0,
#   'DoubleSlashInPath': 0.0,
#   'NumSensitiveWords': 1.0,
#   'EmbeddedBrandName': 0.0,
#   'PctExtHyperlinks': 0.0,
#   'PctExtResourceUrls': 0.0,
#   'ExtFavicon': 0.0,
#   'InsecureForms': 1.0,
#   'RelativeFormAction': 0.0,
#   'ExtFormAction': 0.0,
#   'AbnormalFormAction': 0.0,
#   'PctNullSelfRedirectHyperlinks': 0.0,
#   'FrequentDomainNameMismatch': 0.0,
#   'FakeLinkInStatusBar': 0.0,
#   'RightClickDisabled': 0.0,
#   'PopUpWindow': 0.0,
#   'SubmitInfoToEmail': 0.0,
#   'IframeOrFrame': 0.0,
#   'MissingTitle': 0.0,
#   'ImagesOnlyInForm': 0.0,
#   'SubdomainLevelRT': 1.0,
#   'UrlLengthRT': -1.0,
#   'PctExtResourceUrlsRT': 1.0,
#   'AbnormalExtFormActionR': 1.0,
#   'ExtMetaScriptLinkRT': 1.0,
#   'PctExtNullSelfRedirectHyperlinksRT': 1.0,
#   'CLASS_LABEL': 1.0},
#  {'NumDots': 3.0,
#   'SubdomainLevel': 1.0,
#   'PathLevel': 2.0,
#   'UrlLength': 58.0,
#   'NumDash': 0.0,
#   'NumDashInHostname': 0.0,
#   'AtSymbol': 0.0,
#   'TildeSymbol': 0.0,
#   'NumUnderscore': 0.0,
#   'NumPercent': 0.0,
#   'NumQueryComponents': 0.0,
#   'NumAmpersand': 0.0,
#   'NumHash': 0.0,
#   'NumNumericChars': 0.0,
#   'NoHttps': 1.0,
#   'RandomString': 0.0,
#   'IpAddress': 0.0,
#   'DomainInSubdomains': 0.0,
#   'DomainInPaths': 0.0,
#   'HttpsInHostname': 0.0,
#   'HostnameLength': 27.0,
#   'PathLength': 24.0,
#   'QueryLength': 0.0,
#   'DoubleSlashInPath': 0.0,
#   'NumSensitiveWords': 0.0,
#   'EmbeddedBrandName': 0.0,
#   'PctExtHyperlinks': 0.375,
#   'PctExtResourceUrls': 1.0,
#   'ExtFavicon': 1.0,
#   'InsecureForms': 1.0,
#   'RelativeFormAction': 0.0,
#   'ExtFormAction': 0.0,
#   'AbnormalFormAction': 0.0,
#   'PctNullSelfRedirectHyperlinks': 0.0,
#   'FrequentDomainNameMismatch': 0.0,
#   'FakeLinkInStatusBar': 0.0,
#   'RightClickDisabled': 0.0,
#   'PopUpWindow': 0.0,
#   'SubmitInfoToEmail': 0.0,
#   'IframeOrFrame': 0.0,
#   'MissingTitle': 0.0,
#   'ImagesOnlyInForm': 0.0,
#   'SubdomainLevelRT': 1.0,
#   'UrlLengthRT': 0.0,
#   'PctExtResourceUrlsRT': -1.0,
#   'AbnormalExtFormActionR': 1.0,
#   'ExtMetaScriptLinkRT': -1.0,
#   'PctExtNullSelfRedirectHyperlinksRT': 0.0,
#   'CLASS_LABEL': 1.0},
#  {'NumDots': 3.0,
#   'SubdomainLevel': 1.0,
#   'PathLevel': 6.0,
#   'UrlLength': 79.0,
#   'NumDash': 1.0,
#   'NumDashInHostname': 0.0,
#   'AtSymbol': 0.0,
#   'TildeSymbol': 0.0,
#   'NumUnderscore': 0.0,
#   'NumPercent': 0.0,
#   'NumQueryComponents': 0.0,
#   'NumAmpersand': 0.0,
#   'NumHash': 0.0,
#   'NumNumericChars': 0.0,
#   'NoHttps': 1.0,
#   'RandomString': 0.0,
#   'IpAddress': 0.0,
#   'DomainInSubdomains': 0.0,
#   'DomainInPaths': 1.0,
#   'HttpsInHostname': 0.0,
#   'HostnameLength': 22.0,
#   'PathLength': 50.0,
#   'QueryLength': 0.0,
#   'DoubleSlashInPath': 0.0,
#   'NumSensitiveWords': 0.0,
#   'EmbeddedBrandName': 1.0,
#   'PctExtHyperlinks': 1.0,
#   'PctExtResourceUrls': 0.0952380952,
#   'ExtFavicon': 1.0,
#   'InsecureForms': 1.0,
#   'RelativeFormAction': 0.0,
#   'ExtFormAction': 0.0,
#   'AbnormalFormAction': 0.0,
#   'PctNullSelfRedirectHyperlinks': 0.0,
#   'FrequentDomainNameMismatch': 1.0,
#   'FakeLinkInStatusBar': 0.0,
#   'RightClickDisabled': 0.0,
#   'PopUpWindow': 0.0,
#   'SubmitInfoToEmail': 1.0,
#   'IframeOrFrame': 0.0,
#   'MissingTitle': 0.0,
#   'ImagesOnlyInForm': 0.0,
#   'SubdomainLevelRT': 1.0,
#   'UrlLengthRT': -1.0,
#   'PctExtResourceUrlsRT': 1.0,
#   'AbnormalExtFormActionR': 1.0,
#   'ExtMetaScriptLinkRT': 1.0,
#   'PctExtNullSelfRedirectHyperlinksRT': -1.0,
#   'CLASS_LABEL': 1.0},
#  {'NumDots': 3.0,
#   'SubdomainLevel': 0.0,
#   'PathLevel': 4.0,
#   'UrlLength': 46.0,
#   'NumDash': 0.0,
#   'NumDashInHostname': 0.0,
#   'AtSymbol': 0.0,
#   'TildeSymbol': 0.0,
#   'NumUnderscore': 0.0,
#   'NumPercent': 0.0,
#   'NumQueryComponents': 0.0,
#   'NumAmpersand': 0.0,
#   'NumHash': 0.0,
#   'NumNumericChars': 2.0,
#   'NoHttps': 1.0,
#   'RandomString': 1.0,
#   'IpAddress': 0.0,
#   'DomainInSubdomains': 0.0,
#   'DomainInPaths': 1.0,
#   'HttpsInHostname': 0.0,
#   'HostnameLength': 10.0,
#   'PathLength': 29.0,
#   'QueryLength': 0.0,
#   'DoubleSlashInPath': 0.0,
#   'NumSensitiveWords': 0.0,
#   'EmbeddedBrandName': 0.0,
#   'PctExtHyperlinks': 1.0,
#   'PctExtResourceUrls': 1.0,
#   'ExtFavicon': 0.0,
#   'InsecureForms': 0.0,
#   'RelativeFormAction': 0.0,
#   'ExtFormAction': 1.0,
#   'AbnormalFormAction': 0.0,
#   'PctNullSelfRedirectHyperlinks': 0.0,
#   'FrequentDomainNameMismatch': 1.0,
#   'FakeLinkInStatusBar': 0.0,
#   'RightClickDisabled': 0.0,
#   'PopUpWindow': 0.0,
#   'SubmitInfoToEmail': 0.0,
#   'IframeOrFrame': 1.0,
#   'MissingTitle': 0.0,
#   'ImagesOnlyInForm': 0.0,
#   'SubdomainLevelRT': 1.0,
#   'UrlLengthRT': 1.0,
#   'PctExtResourceUrlsRT': -1.0,
#   'AbnormalExtFormActionR': 0.0,
#   'ExtMetaScriptLinkRT': -1.0,
#   'PctExtNullSelfRedirectHyperlinksRT': -1.0,
#   'CLASS_LABEL': 1.0},
#  {'NumDots': 3.0,
#   'SubdomainLevel': 1.0,
#   'PathLevel': 1.0,
#   'UrlLength': 42.0,
#   'NumDash': 1.0,
#   'NumDashInHostname': 0.0,
#   'AtSymbol': 0.0,
#   'TildeSymbol': 0.0,
#   'NumUnderscore': 0.0,
#   'NumPercent': 0.0,
#   'NumQueryComponents': 0.0,
#   'NumAmpersand': 0.0,
#   'NumHash': 0.0,
#   'NumNumericChars': 0.0,
#   'NoHttps': 1.0,
#   'RandomString': 0.0,
#   'IpAddress': 0.0,
#   'DomainInSubdomains': 0.0,
#   'DomainInPaths': 1.0,
#   'HttpsInHostname': 0.0,
#   'HostnameLength': 23.0,
#   'PathLength': 12.0,
#   'QueryLength': 0.0,
#   'DoubleSlashInPath': 0.0,
#   'NumSensitiveWords': 0.0,
#   'EmbeddedBrandName': 0.0,
#   'PctExtHyperlinks': 0.1,
#   'PctExtResourceUrls': 1.0,
#   'ExtFavicon': 1.0,
#   'InsecureForms': 1.0,
#   'RelativeFormAction': 0.0,
#   'ExtFormAction': 0.0,
#   'AbnormalFormAction': 0.0,
#   'PctNullSelfRedirectHyperlinks': 0.0,
#   'FrequentDomainNameMismatch': 0.0,
#   'FakeLinkInStatusBar': 0.0,
#   'RightClickDisabled': 0.0,
#   'PopUpWindow': 0.0,
#   'SubmitInfoToEmail': 0.0,
#   'IframeOrFrame': 1.0,
#   'MissingTitle': 1.0,
#   'ImagesOnlyInForm': 0.0,
#   'SubdomainLevelRT': 1.0,
#   'UrlLengthRT': 1.0,
#   'PctExtResourceUrlsRT': 1.0,
#   'AbnormalExtFormActionR': 1.0,
#   'ExtMetaScriptLinkRT': -1.0,
#   'PctExtNullSelfRedirectHyperlinksRT': 1.0,
#   'CLASS_LABEL': 1.0},
#  {'NumDots': 2.0,
#   'SubdomainLevel': 0.0,
#   'PathLevel': 5.0,
#   'UrlLength': 60.0,
#   'NumDash': 0.0,
#   'NumDashInHostname': 0.0,
#   'AtSymbol': 0.0,
#   'TildeSymbol': 0.0,
#   'NumUnderscore': 0.0,
#   'NumPercent': 0.0,
#   'NumQueryComponents': 0.0,
#   'NumAmpersand': 0.0,
#   'NumHash': 0.0,
#   'NumNumericChars': 1.0,
#   'NoHttps': 1.0,
#   'RandomString': 0.0,
#   'IpAddress': 0.0,
#   'DomainInSubdomains': 0.0,
#   'DomainInPaths': 1.0,
#   'HttpsInHostname': 0.0,
#   'HostnameLength': 17.0,
#   'PathLength': 36.0,
#   'QueryLength': 0.0,
#   'DoubleSlashInPath': 0.0,
#   'NumSensitiveWords': 0.0,
#   'EmbeddedBrandName': 1.0,
#   'PctExtHyperlinks': 0.9090909091,
#   'PctExtResourceUrls': 1.0,
#   'ExtFavicon': 0.0,
#   'InsecureForms': 1.0,
#   'RelativeFormAction': 0.0,
#   'ExtFormAction': 0.0,
#   'AbnormalFormAction': 0.0,
#   'PctNullSelfRedirectHyperlinks': 0.0,
#   'FrequentDomainNameMismatch': 1.0,
#   'FakeLinkInStatusBar': 0.0,
#   'RightClickDisabled': 0.0,
#   'PopUpWindow': 0.0,
#   'SubmitInfoToEmail': 0.0,
#   'IframeOrFrame': 0.0,
#   'MissingTitle': 0.0,
#   'ImagesOnlyInForm': 0.0,
#   'SubdomainLevelRT': 1.0,
#   'UrlLengthRT': 0.0,
#   'PctExtResourceUrlsRT': 1.0,
#   'AbnormalExtFormActionR': 1.0,
#   'ExtMetaScriptLinkRT': -1.0,
#   'PctExtNullSelfRedirectHyperlinksRT': -1.0,
#   'CLASS_LABEL': 1.0},
#  {'NumDots': 1.0,
#   'SubdomainLevel': 0.0,
#   'PathLevel': 3.0,
#   'UrlLength': 30.0,
#   'NumDash': 0.0,
#   'NumDashInHostname': 0.0,
#   'AtSymbol': 0.0,
#   'TildeSymbol': 0.0,
#   'NumUnderscore': 0.0,
#   'NumPercent': 0.0,
#   'NumQueryComponents': 0.0,
#   'NumAmpersand': 0.0,
#   'NumHash': 0.0,
#   'NumNumericChars': 3.0,
#   'NoHttps': 1.0,
#   'RandomString': 1.0,
#   'IpAddress': 0.0,
#   'DomainInSubdomains': 0.0,
#   'DomainInPaths': 1.0,
#   'HttpsInHostname': 0.0,
#   'HostnameLength': 12.0,
#   'PathLength': 11.0,
#   'QueryLength': 0.0,
#   'DoubleSlashInPath': 0.0,
#   'NumSensitiveWords': 0.0,
#   'EmbeddedBrandName': 0.0,
#   'PctExtHyperlinks': 0.0,
#   'PctExtResourceUrls': 0.0,
#   'ExtFavicon': 0.0,
#   'InsecureForms': 1.0,
#   'RelativeFormAction': 0.0,
#   'ExtFormAction': 0.0,
#   'AbnormalFormAction': 0.0,
#   'PctNullSelfRedirectHyperlinks': 0.0,
#   'FrequentDomainNameMismatch': 0.0,
#   'FakeLinkInStatusBar': 0.0,
#   'RightClickDisabled': 0.0,
#   'PopUpWindow': 0.0,
#   'SubmitInfoToEmail': 0.0,
#   'IframeOrFrame': 0.0,
#   'MissingTitle': 0.0,
#   'ImagesOnlyInForm': 0.0,
#   'SubdomainLevelRT': 1.0,
#   'UrlLengthRT': 1.0,
#   'PctExtResourceUrlsRT': 1.0,
#   'AbnormalExtFormActionR': 1.0,
#   'ExtMetaScriptLinkRT': 1.0,
#   'PctExtNullSelfRedirectHyperlinksRT': 1.0,
#   'CLASS_LABEL': 1.0},
#  {'NumDots': 8.0,
#   'SubdomainLevel': 7.0,
#   'PathLevel': 2.0,
#   'UrlLength': 76.0,
#   'NumDash': 1.0,
#   'NumDashInHostname': 1.0,
#   'AtSymbol': 0.0,
#   'TildeSymbol': 0.0,
#   'NumUnderscore': 0.0,
#   'NumPercent': 0.0,
#   'NumQueryComponents': 0.0,
#   'NumAmpersand': 0.0,
#   'NumHash': 0.0,
#   'NumNumericChars': 2.0,
#   'NoHttps': 1.0,
#   'RandomString': 1.0,
#   'IpAddress': 0.0,
#   'DomainInSubdomains': 1.0,
#   'DomainInPaths': 1.0,
#   'HttpsInHostname': 0.0,
#   'HostnameLength': 65.0,
#   'PathLength': 4.0,
#   'QueryLength': 0.0,
#   'DoubleSlashInPath': 0.0,
#   'NumSensitiveWords': 0.0,
#   'EmbeddedBrandName': 0.0,
#   'PctExtHyperlinks': 0.0,
#   'PctExtResourceUrls': 0.0,
#   'ExtFavicon': 0.0,
#   'InsecureForms': 1.0,
#   'RelativeFormAction': 0.0,
#   'ExtFormAction': 0.0,
#   'AbnormalFormAction': 0.0,
#   'PctNullSelfRedirectHyperlinks': 0.975,
#   'FrequentDomainNameMismatch': 0.0,
#   'FakeLinkInStatusBar': 0.0,
#   'RightClickDisabled': 0.0,
#   'PopUpWindow': 0.0,
#   'SubmitInfoToEmail': 0.0,
#   'IframeOrFrame': 0.0,
#   'MissingTitle': 0.0,
#   'ImagesOnlyInForm': 0.0,
#   'SubdomainLevelRT': -1.0,
#   'UrlLengthRT': -1.0,
#   'PctExtResourceUrlsRT': 1.0,
#   'AbnormalExtFormActionR': 1.0,
#   'ExtMetaScriptLinkRT': 1.0,
#   'PctExtNullSelfRedirectHyperlinksRT': -1.0,
#   'CLASS_LABEL': 1.0},
#  {'NumDots': 2.0,
#   'SubdomainLevel': 0.0,
#   'PathLevel': 2.0,
#   'UrlLength': 46.0,
#   'NumDash': 0.0,
#   'NumDashInHostname': 0.0,
#   'AtSymbol': 0.0,
#   'TildeSymbol': 0.0,
#   'NumUnderscore': 0.0,
#   'NumPercent': 0.0,
#   'NumQueryComponents': 0.0,
#   'NumAmpersand': 0.0,
#   'NumHash': 0.0,
#   'NumNumericChars': 0.0,
#   'NoHttps': 1.0,
#   'RandomString': 0.0,
#   'IpAddress': 0.0,
#   'DomainInSubdomains': 0.0,
#   'DomainInPaths': 1.0,
#   'HttpsInHostname': 0.0,
#   'HostnameLength': 14.0,
#   'PathLength': 25.0,
#   'QueryLength': 0.0,
#   'DoubleSlashInPath': 0.0,
#   'NumSensitiveWords': 0.0,
#   'EmbeddedBrandName': 1.0,
#   'PctExtHyperlinks': 1.0,
#   'PctExtResourceUrls': 1.0,
#   'ExtFavicon': 1.0,
#   'InsecureForms': 1.0,
#   'RelativeFormAction': 0.0,
#   'ExtFormAction': 0.0,
#   'AbnormalFormAction': 0.0,
#   'PctNullSelfRedirectHyperlinks': 0.0,
#   'FrequentDomainNameMismatch': 1.0,
#   'FakeLinkInStatusBar': 0.0,
#   'RightClickDisabled': 0.0,
#   'PopUpWindow': 0.0,
#   'SubmitInfoToEmail': 0.0,
#   'IframeOrFrame': 0.0,
#   'MissingTitle': 0.0,
#   'ImagesOnlyInForm': 0.0,
#   'SubdomainLevelRT': 1.0,
#   'UrlLengthRT': 1.0,
#   'PctExtResourceUrlsRT': 1.0,
#   'AbnormalExtFormActionR': 1.0,
#   'ExtMetaScriptLinkRT': -1.0,
#   'PctExtNullSelfRedirectHyperlinksRT': -1.0,
#   'CLASS_LABEL': 1.0},
#  {'NumDots': 5.0,
#   'SubdomainLevel': 4.0,
#   'PathLevel': 2.0,
#   'UrlLength': 64.0,
#   'NumDash': 1.0,
#   'NumDashInHostname': 1.0,
#   'AtSymbol': 0.0,
#   'TildeSymbol': 0.0,
#   'NumUnderscore': 0.0,
#   'NumPercent': 0.0,
#   'NumQueryComponents': 0.0,
#   'NumAmpersand': 0.0,
#   'NumHash': 0.0,
#   'NumNumericChars': 3.0,
#   'NoHttps': 1.0,
#   'RandomString': 1.0,
#   'IpAddress': 0.0,
#   'DomainInSubdomains': 1.0,
#   'DomainInPaths': 1.0,
#   'HttpsInHostname': 0.0,
#   'HostnameLength': 53.0,
#   'PathLength': 4.0,
#   'QueryLength': 0.0,
#   'DoubleSlashInPath': 0.0,
#   'NumSensitiveWords': 0.0,
#   'EmbeddedBrandName': 0.0,
#   'PctExtHyperlinks': 0.0,
#   'PctExtResourceUrls': 0.0,
#   'ExtFavicon': 0.0,
#   'InsecureForms': 1.0,
#   'RelativeFormAction': 0.0,
#   'ExtFormAction': 0.0,
#   'AbnormalFormAction': 0.0,
#   'PctNullSelfRedirectHyperlinks': 0.975,
#   'FrequentDomainNameMismatch': 0.0,
#   'FakeLinkInStatusBar': 0.0,
#   'RightClickDisabled': 0.0,
#   'PopUpWindow': 0.0,
#   'SubmitInfoToEmail': 0.0,
#   'IframeOrFrame': 0.0,
#   'MissingTitle': 0.0,
#   'ImagesOnlyInForm': 0.0,
#   'SubdomainLevelRT': -1.0,
#   'UrlLengthRT': 0.0,
#   'PctExtResourceUrlsRT': 1.0,
#   'AbnormalExtFormActionR': 1.0,
#   'ExtMetaScriptLinkRT': 1.0,
#   'PctExtNullSelfRedirectHyperlinksRT': -1.0,
#   'CLASS_LABEL': 1.0},
#  {'NumDots': 2.0,
#   'SubdomainLevel': 0.0,
#   'PathLevel': 2.0,
#   'UrlLength': 47.0,
#   'NumDash': 0.0,
#   'NumDashInHostname': 0.0,
#   'AtSymbol': 0.0,
#   'TildeSymbol': 0.0,
#   'NumUnderscore': 0.0,
#   'NumPercent': 0.0,
#   'NumQueryComponents': 0.0,
#   'NumAmpersand': 0.0,
#   'NumHash': 0.0,
#   'NumNumericChars': 1.0,
#   'NoHttps': 1.0,
#   'RandomString': 0.0,
#   'IpAddress': 0.0,
#   'DomainInSubdomains': 0.0,
#   'DomainInPaths': 0.0,
#   'HttpsInHostname': 0.0,
#   'HostnameLength': 22.0,
#   'PathLength': 18.0,
#   'QueryLength': 0.0,
#   'DoubleSlashInPath': 0.0,
#   'NumSensitiveWords': 1.0,
#   'EmbeddedBrandName': 0.0,
#   'PctExtHyperlinks': 1.0,
#   'PctExtResourceUrls': 1.0,
#   'ExtFavicon': 1.0,
#   'InsecureForms': 1.0,
#   'RelativeFormAction': 0.0,
#   'ExtFormAction': 0.0,
#   'AbnormalFormAction': 0.0,
#   'PctNullSelfRedirectHyperlinks': 0.0,
#   'FrequentDomainNameMismatch': 1.0,
#   'FakeLinkInStatusBar': 0.0,
#   'RightClickDisabled': 0.0,
#   'PopUpWindow': 0.0,
#   'SubmitInfoToEmail': 0.0,
#   'IframeOrFrame': 0.0,
#   'MissingTitle': 0.0,
#   'ImagesOnlyInForm': 0.0,
#   'SubdomainLevelRT': 1.0,
#   'UrlLengthRT': 1.0,
#   'PctExtResourceUrlsRT': -1.0,
#   'AbnormalExtFormActionR': 1.0,
#   'ExtMetaScriptLinkRT': -1.0,
#   'PctExtNullSelfRedirectHyperlinksRT': -1.0,
#   'CLASS_LABEL': 1.0},
#  {'NumDots': 2.0,
#   'SubdomainLevel': 1.0,
#   'PathLevel': 2.0,
#   'UrlLength': 61.0,
#   'NumDash': 1.0,
#   'NumDashInHostname': 1.0,
#   'AtSymbol': 0.0,
#   'TildeSymbol': 0.0,
#   'NumUnderscore': 0.0,
#   'NumPercent': 0.0,
#   'NumQueryComponents': 0.0,
#   'NumAmpersand': 0.0,
#   'NumHash': 0.0,
#   'NumNumericChars': 0.0,
#   'NoHttps': 0.0,
#   'RandomString': 1.0,
#   'IpAddress': 0.0,
#   'DomainInSubdomains': 0.0,
#   'DomainInPaths': 0.0,
#   'HttpsInHostname': 0.0,
#   'HostnameLength': 43.0,
#   'PathLength': 10.0,
#   'QueryLength': 0.0,
#   'DoubleSlashInPath': 0.0,
#   'NumSensitiveWords': 0.0,
#   'EmbeddedBrandName': 0.0,
#   'PctExtHyperlinks': 0.0,
#   'PctExtResourceUrls': 0.0,
#   'ExtFavicon': 0.0,
#   'InsecureForms': 0.0,
#   'RelativeFormAction': 1.0,
#   'ExtFormAction': 0.0,
#   'AbnormalFormAction': 0.0,
#   'PctNullSelfRedirectHyperlinks': 1.0,
#   'FrequentDomainNameMismatch': 0.0,
#   'FakeLinkInStatusBar': 0.0,
#   'RightClickDisabled': 0.0,
#   'PopUpWindow': 0.0,
#   'SubmitInfoToEmail': 0.0,
#   'IframeOrFrame': 0.0,
#   'MissingTitle': 0.0,
#   'ImagesOnlyInForm': 0.0,
#   'SubdomainLevelRT': 1.0,
#   'UrlLengthRT': 0.0,
#   'PctExtResourceUrlsRT': 1.0,
#   'AbnormalExtFormActionR': 1.0,
#   'ExtMetaScriptLinkRT': 1.0,
#   'PctExtNullSelfRedirectHyperlinksRT': -1.0,
#   'CLASS_LABEL': 1.0},
#  {'NumDots': 2.0,
#   'SubdomainLevel': 1.0,
#   'PathLevel': 3.0,
#   'UrlLength': 35.0,
#   'NumDash': 0.0,
#   'NumDashInHostname': 0.0,
#   'AtSymbol': 0.0,
#   'TildeSymbol': 0.0,
#   'NumUnderscore': 0.0,
#   'NumPercent': 0.0,
#   'NumQueryComponents': 0.0,
#   'NumAmpersand': 0.0,
#   'NumHash': 0.0,
#   'NumNumericChars': 0.0,
#   'NoHttps': 1.0,
#   'RandomString': 0.0,
#   'IpAddress': 0.0,
#   'DomainInSubdomains': 0.0,
#   'DomainInPaths': 0.0,
#   'HttpsInHostname': 0.0,
#   'HostnameLength': 16.0,
#   'PathLength': 12.0,
#   'QueryLength': 0.0,
#   'DoubleSlashInPath': 0.0,
#   'NumSensitiveWords': 0.0,
#   'EmbeddedBrandName': 0.0,
#   'PctExtHyperlinks': 0.0,
#   'PctExtResourceUrls': 0.0,
#   'ExtFavicon': 0.0,
#   'InsecureForms': 1.0,
#   'RelativeFormAction': 0.0,
#   'ExtFormAction': 1.0,
#   'AbnormalFormAction': 0.0,
#   'PctNullSelfRedirectHyperlinks': 0.0,
#   'FrequentDomainNameMismatch': 0.0,
#   'FakeLinkInStatusBar': 0.0,
#   'RightClickDisabled': 0.0,
#   'PopUpWindow': 0.0,
#   'SubmitInfoToEmail': 0.0,
#   'IframeOrFrame': 0.0,
#   'MissingTitle': 0.0,
#   'ImagesOnlyInForm': 0.0,
#   'SubdomainLevelRT': 1.0,
#   'UrlLengthRT': 1.0,
#   'PctExtResourceUrlsRT': 1.0,
#   'AbnormalExtFormActionR': 0.0,
#   'ExtMetaScriptLinkRT': 1.0,
#   'PctExtNullSelfRedirectHyperlinksRT': 1.0,
#   'CLASS_LABEL': 1.0},
#  {'NumDots': 2.0,
#   'SubdomainLevel': 1.0,
#   'PathLevel': 2.0,
#   'UrlLength': 60.0,
#   'NumDash': 1.0,
#   'NumDashInHostname': 1.0,
#   'AtSymbol': 0.0,
#   'TildeSymbol': 0.0,
#   'NumUnderscore': 0.0,
#   'NumPercent': 0.0,
#   'NumQueryComponents': 0.0,
#   'NumAmpersand': 0.0,
#   'NumHash': 0.0,
#   'NumNumericChars': 0.0,
#   'NoHttps': 1.0,
#   'RandomString': 1.0,
#   'IpAddress': 0.0,
#   'DomainInSubdomains': 0.0,
#   'DomainInPaths': 0.0,
#   'HttpsInHostname': 0.0,
#   'HostnameLength': 43.0,
#   'PathLength': 10.0,
#   'QueryLength': 0.0,
#   'DoubleSlashInPath': 0.0,
#   'NumSensitiveWords': 0.0,
#   'EmbeddedBrandName': 0.0,
#   'PctExtHyperlinks': 0.0,
#   'PctExtResourceUrls': 0.0,
#   'ExtFavicon': 0.0,
#   'InsecureForms': 1.0,
#   'RelativeFormAction': 1.0,
#   'ExtFormAction': 0.0,
#   'AbnormalFormAction': 0.0,
#   'PctNullSelfRedirectHyperlinks': 1.0,
#   'FrequentDomainNameMismatch': 0.0,
#   'FakeLinkInStatusBar': 0.0,
#   'RightClickDisabled': 0.0,
#   'PopUpWindow': 0.0,
#   'SubmitInfoToEmail': 0.0,
#   'IframeOrFrame': 0.0,
#   'MissingTitle': 0.0,
#   'ImagesOnlyInForm': 0.0,
#   'SubdomainLevelRT': 1.0,
#   'UrlLengthRT': 0.0,
#   'PctExtResourceUrlsRT': 1.0,
#   'AbnormalExtFormActionR': 1.0,
#   'ExtMetaScriptLinkRT': 1.0,
#   'PctExtNullSelfRedirectHyperlinksRT': -1.0,
#   'CLASS_LABEL': 1.0},
#  {'NumDots': 3.0,
#   'SubdomainLevel': 0.0,
#   'PathLevel': 4.0,
#   'UrlLength': 73.0,
#   'NumDash': 0.0,
#   'NumDashInHostname': 0.0,
#   'AtSymbol': 0.0,
#   'TildeSymbol': 0.0,
#   'NumUnderscore': 0.0,
#   'NumPercent': 0.0,
#   'NumQueryComponents': 0.0,
#   'NumAmpersand': 0.0,
#   'NumHash': 0.0,
#   'NumNumericChars': 0.0,
#   'NoHttps': 1.0,
#   'RandomString': 0.0,
#   'IpAddress': 0.0,
#   'DomainInSubdomains': 0.0,
#   'DomainInPaths': 1.0,
#   'HttpsInHostname': 0.0,
#   'HostnameLength': 33.0,
#   'PathLength': 33.0,
#   'QueryLength': 0.0,
#   'DoubleSlashInPath': 0.0,
#   'NumSensitiveWords': 1.0,
#   'EmbeddedBrandName': 0.0,
#   'PctExtHyperlinks': 1.0,
#   'PctExtResourceUrls': 0.0769230769,
#   'ExtFavicon': 0.0,
#   'InsecureForms': 1.0,
#   'RelativeFormAction': 1.0,
#   'ExtFormAction': 0.0,
#   'AbnormalFormAction': 0.0,
#   'PctNullSelfRedirectHyperlinks': 0.0,
#   'FrequentDomainNameMismatch': 0.0,
#   'FakeLinkInStatusBar': 0.0,
#   'RightClickDisabled': 0.0,
#   'PopUpWindow': 0.0,
#   'SubmitInfoToEmail': 0.0,
#   'IframeOrFrame': 0.0,
#   'MissingTitle': 0.0,
#   'ImagesOnlyInForm': 0.0,
#   'SubdomainLevelRT': 1.0,
#   'UrlLengthRT': 0.0,
#   'PctExtResourceUrlsRT': 1.0,
#   'AbnormalExtFormActionR': 1.0,
#   'ExtMetaScriptLinkRT': 0.0,
#   'PctExtNullSelfRedirectHyperlinksRT': -1.0,
#   'CLASS_LABEL': 1.0},
#  {'NumDots': 3.0,
#   'SubdomainLevel': 0.0,
#   'PathLevel': 5.0,
#   'UrlLength': 50.0,
#   'NumDash': 0.0,
#   'NumDashInHostname': 0.0,
#   'AtSymbol': 0.0,
#   'TildeSymbol': 1.0,
#   'NumUnderscore': 0.0,
#   'NumPercent': 0.0,
#   'NumQueryComponents': 0.0,
#   'NumAmpersand': 0.0,
#   'NumHash': 0.0,
#   'NumNumericChars': 10.0,
#   'NoHttps': 1.0,
#   'RandomString': 1.0,
#   'IpAddress': 1.0,
#   'DomainInSubdomains': 0.0,
#   'DomainInPaths': 0.0,
#   'HttpsInHostname': 0.0,
#   'HostnameLength': 13.0,
#   'PathLength': 30.0,
#   'QueryLength': 0.0,
#   'DoubleSlashInPath': 0.0,
#   'NumSensitiveWords': 0.0,
#   'EmbeddedBrandName': 0.0,
#   'PctExtHyperlinks': 0.0,
#   'PctExtResourceUrls': 0.0,
#   'ExtFavicon': 0.0,
#   'InsecureForms': 1.0,
#   'RelativeFormAction': 0.0,
#   'ExtFormAction': 0.0,
#   'AbnormalFormAction': 0.0,
#   'PctNullSelfRedirectHyperlinks': 0.0,
#   'FrequentDomainNameMismatch': 1.0,
#   'FakeLinkInStatusBar': 0.0,
#   'RightClickDisabled': 0.0,
#   'PopUpWindow': 0.0,
#   'SubmitInfoToEmail': 0.0,
#   'IframeOrFrame': 0.0,
#   'MissingTitle': 0.0,
#   'ImagesOnlyInForm': 0.0,
#   'SubdomainLevelRT': 1.0,
#   'UrlLengthRT': 1.0,
#   'PctExtResourceUrlsRT': 1.0,
#   'AbnormalExtFormActionR': 1.0,
#   'ExtMetaScriptLinkRT': 1.0,
#   'PctExtNullSelfRedirectHyperlinksRT': 1.0,
#   'CLASS_LABEL': 1.0},
#  {'NumDots': 3.0,
#   'SubdomainLevel': 1.0,
#   'PathLevel': 2.0,
#   'UrlLength': 59.0,
#   'NumDash': 1.0,
#   'NumDashInHostname': 1.0,
#   'AtSymbol': 0.0,
#   'TildeSymbol': 0.0,
#   'NumUnderscore': 0.0,
#   'NumPercent': 0.0,
#   'NumQueryComponents': 0.0,
#   'NumAmpersand': 0.0,
#   'NumHash': 0.0,
#   'NumNumericChars': 7.0,
#   'NoHttps': 1.0,
#   'RandomString': 1.0,
#   'IpAddress': 0.0,
#   'DomainInSubdomains': 0.0,
#   'DomainInPaths': 1.0,
#   'HttpsInHostname': 0.0,
#   'HostnameLength': 36.0,
#   'PathLength': 16.0,
#   'QueryLength': 0.0,
#   'DoubleSlashInPath': 0.0,
#   'NumSensitiveWords': 0.0,
#   'EmbeddedBrandName': 0.0,
#   'PctExtHyperlinks': 1.0,
#   'PctExtResourceUrls': 1.0,
#   'ExtFavicon': 1.0,
#   'InsecureForms': 1.0,
#   'RelativeFormAction': 0.0,
#   'ExtFormAction': 0.0,
#   'AbnormalFormAction': 0.0,
#   'PctNullSelfRedirectHyperlinks': 0.0,
#   'FrequentDomainNameMismatch': 1.0,
#   'FakeLinkInStatusBar': 0.0,
#   'RightClickDisabled': 0.0,
#   'PopUpWindow': 0.0,
#   'SubmitInfoToEmail': 0.0,
#   'IframeOrFrame': 1.0,
#   'MissingTitle': 0.0,
#   'ImagesOnlyInForm': 0.0,
#   'SubdomainLevelRT': 1.0,
#   'UrlLengthRT': 0.0,
#   'PctExtResourceUrlsRT': -1.0,
#   'AbnormalExtFormActionR': 1.0,
#   'ExtMetaScriptLinkRT': -1.0,
#   'PctExtNullSelfRedirectHyperlinksRT': -1.0,
#   'CLASS_LABEL': 1.0},
#  {'NumDots': 2.0,
#   'SubdomainLevel': 0.0,
#   'PathLevel': 3.0,
#   'UrlLength': 28.0,
#   'NumDash': 0.0,
#   'NumDashInHostname': 0.0,
#   'AtSymbol': 0.0,
#   'TildeSymbol': 0.0,
#   'NumUnderscore': 0.0,
#   'NumPercent': 0.0,
#   'NumQueryComponents': 0.0,
#   'NumAmpersand': 0.0,
#   'NumHash': 0.0,
#   'NumNumericChars': 1.0,
#   'NoHttps': 1.0,
#   'RandomString': 0.0,
#   'IpAddress': 0.0,
#   'DomainInSubdomains': 0.0,
#   'DomainInPaths': 1.0,
#   'HttpsInHostname': 0.0,
#   'HostnameLength': 9.0,
#   'PathLength': 12.0,
#   'QueryLength': 0.0,
#   'DoubleSlashInPath': 0.0,
#   'NumSensitiveWords': 0.0,
#   'EmbeddedBrandName': 0.0,
#   'PctExtHyperlinks': 0.0,
#   'PctExtResourceUrls': 0.0,
#   'ExtFavicon': 0.0,
#   'InsecureForms': 1.0,
#   'RelativeFormAction': 0.0,
#   'ExtFormAction': 0.0,
#   'AbnormalFormAction': 0.0,
#   'PctNullSelfRedirectHyperlinks': 0.0,
#   'FrequentDomainNameMismatch': 0.0,
#   'FakeLinkInStatusBar': 0.0,
#   'RightClickDisabled': 0.0,
#   'PopUpWindow': 0.0,
#   'SubmitInfoToEmail': 0.0,
#   'IframeOrFrame': 0.0,
#   'MissingTitle': 0.0,
#   'ImagesOnlyInForm': 0.0,
#   'SubdomainLevelRT': 1.0,
#   'UrlLengthRT': 1.0,
#   'PctExtResourceUrlsRT': 1.0,
#   'AbnormalExtFormActionR': 1.0,
#   'ExtMetaScriptLinkRT': 1.0,
#   'PctExtNullSelfRedirectHyperlinksRT': 1.0,
#   'CLASS_LABEL': 1.0},
#  {'NumDots': 1.0,
#   'SubdomainLevel': 0.0,
#   'PathLevel': 4.0,
#   'UrlLength': 59.0,
#   'NumDash': 0.0,
#   'NumDashInHostname': 0.0,
#   'AtSymbol': 0.0,
#   'TildeSymbol': 0.0,
#   'NumUnderscore': 0.0,
#   'NumPercent': 0.0,
#   'NumQueryComponents': 0.0,
#   'NumAmpersand': 0.0,
#   'NumHash': 0.0,
#   'NumNumericChars': 22.0,
#   'NoHttps': 1.0,
#   'RandomString': 1.0,
#   'IpAddress': 0.0,
#   'DomainInSubdomains': 0.0,
#   'DomainInPaths': 1.0,
#   'HttpsInHostname': 0.0,
#   'HostnameLength': 12.0,
#   'PathLength': 40.0,
#   'QueryLength': 0.0,
#   'DoubleSlashInPath': 0.0,
#   'NumSensitiveWords': 0.0,
#   'EmbeddedBrandName': 0.0,
#   'PctExtHyperlinks': 0.0,
#   'PctExtResourceUrls': 0.125,
#   'ExtFavicon': 0.0,
#   'InsecureForms': 1.0,
#   'RelativeFormAction': 1.0,
#   'ExtFormAction': 0.0,
#   'AbnormalFormAction': 0.0,
#   'PctNullSelfRedirectHyperlinks': 0.9230769231,
#   'FrequentDomainNameMismatch': 0.0,
#   'FakeLinkInStatusBar': 0.0,
#   'RightClickDisabled': 0.0,
#   'PopUpWindow': 0.0,
#   'SubmitInfoToEmail': 0.0,
#   'IframeOrFrame': 0.0,
#   'MissingTitle': 0.0,
#   'ImagesOnlyInForm': 0.0,
#   'SubdomainLevelRT': 1.0,
#   'UrlLengthRT': 0.0,
#   'PctExtResourceUrlsRT': 1.0,
#   'AbnormalExtFormActionR': 1.0,
#   'ExtMetaScriptLinkRT': 1.0,
#   'PctExtNullSelfRedirectHyperlinksRT': -1.0,
#   'CLASS_LABEL': 1.0},
#  {'NumDots': 1.0,
#   'SubdomainLevel': 0.0,
#   'PathLevel': 4.0,
#   'UrlLength': 32.0,
#   'NumDash': 0.0,
#   'NumDashInHostname': 0.0,
#   'AtSymbol': 0.0,
#   'TildeSymbol': 0.0,
#   'NumUnderscore': 0.0,
#   'NumPercent': 0.0,
#   'NumQueryComponents': 0.0,
#   'NumAmpersand': 0.0,
#   'NumHash': 0.0,
#   'NumNumericChars': 4.0,
#   'NoHttps': 1.0,
#   'RandomString': 1.0,
#   'IpAddress': 0.0,
#   'DomainInSubdomains': 0.0,
#   'DomainInPaths': 0.0,
#   'HttpsInHostname': 0.0,
#   'HostnameLength': 11.0,
#   'PathLength': 14.0,
#   'QueryLength': 0.0,
#   'DoubleSlashInPath': 0.0,
#   'NumSensitiveWords': 0.0,
#   'EmbeddedBrandName': 0.0,
#   'PctExtHyperlinks': 0.0,
#   'PctExtResourceUrls': 0.0,
#   'ExtFavicon': 0.0,
#   'InsecureForms': 1.0,
#   'RelativeFormAction': 0.0,
#   'ExtFormAction': 0.0,
#   'AbnormalFormAction': 0.0,
#   'PctNullSelfRedirectHyperlinks': 1.0,
#   'FrequentDomainNameMismatch': 0.0,
#   'FakeLinkInStatusBar': 0.0,
#   'RightClickDisabled': 0.0,
#   'PopUpWindow': 0.0,
#   'SubmitInfoToEmail': 0.0,
#   'IframeOrFrame': 0.0,
#   'MissingTitle': 0.0,
#   'ImagesOnlyInForm': 1.0,
#   'SubdomainLevelRT': 1.0,
#   'UrlLengthRT': 1.0,
#   'PctExtResourceUrlsRT': 1.0,
#   'AbnormalExtFormActionR': 1.0,
#   'ExtMetaScriptLinkRT': 1.0,
#   'PctExtNullSelfRedirectHyperlinksRT': -1.0,
#   'CLASS_LABEL': 1.0},
#  {'NumDots': 5.0,
#   'SubdomainLevel': 1.0,
#   'PathLevel': 2.0,
#   'UrlLength': 52.0,
#   'NumDash': 0.0,
#   'NumDashInHostname': 0.0,
#   'AtSymbol': 0.0,
#   'TildeSymbol': 0.0,
#   'NumUnderscore': 0.0,
#   'NumPercent': 0.0,
#   'NumQueryComponents': 0.0,
#   'NumAmpersand': 0.0,
#   'NumHash': 0.0,
#   'NumNumericChars': 1.0,
#   'NoHttps': 1.0,
#   'RandomString': 1.0,
#   'IpAddress': 0.0,
#   'DomainInSubdomains': 0.0,
#   'DomainInPaths': 0.0,
#   'HttpsInHostname': 0.0,
#   'HostnameLength': 25.0,
#   'PathLength': 20.0,
#   'QueryLength': 0.0,
#   'DoubleSlashInPath': 0.0,
#   'NumSensitiveWords': 0.0,
#   'EmbeddedBrandName': 0.0,
#   'PctExtHyperlinks': 0.0,
#   'PctExtResourceUrls': 0.1538461538,
#   'ExtFavicon': 0.0,
#   'InsecureForms': 1.0,
#   'RelativeFormAction': 0.0,
#   'ExtFormAction': 0.0,
#   'AbnormalFormAction': 0.0,
#   'PctNullSelfRedirectHyperlinks': 0.0,
#   'FrequentDomainNameMismatch': 0.0,
#   'FakeLinkInStatusBar': 0.0,
#   'RightClickDisabled': 0.0,
#   'PopUpWindow': 0.0,
#   'SubmitInfoToEmail': 0.0,
#   'IframeOrFrame': 0.0,
#   'MissingTitle': 0.0,
#   'ImagesOnlyInForm': 0.0,
#   'SubdomainLevelRT': 1.0,
#   'UrlLengthRT': 1.0,
#   'PctExtResourceUrlsRT': 1.0,
#   'AbnormalExtFormActionR': 1.0,
#   'ExtMetaScriptLinkRT': 1.0,
#   'PctExtNullSelfRedirectHyperlinksRT': 1.0,
#   'CLASS_LABEL': 1.0},
#  {'NumDots': 2.0,
#   'SubdomainLevel': 1.0,
#   'PathLevel': 6.0,
#   'UrlLength': 62.0,
#   'NumDash': 1.0,
#   'NumDashInHostname': 0.0,
#   'AtSymbol': 0.0,
#   'TildeSymbol': 0.0,
#   'NumUnderscore': 0.0,
#   'NumPercent': 0.0,
#   'NumQueryComponents': 0.0,
#   'NumAmpersand': 0.0,
#   'NumHash': 0.0,
#   'NumNumericChars': 0.0,
#   'NoHttps': 1.0,
#   'RandomString': 1.0,
#   'IpAddress': 0.0,
#   'DomainInSubdomains': 0.0,
#   'DomainInPaths': 0.0,
#   'HttpsInHostname': 0.0,
#   'HostnameLength': 18.0,
#   'PathLength': 37.0,
#   'QueryLength': 0.0,
#   'DoubleSlashInPath': 0.0,
#   'NumSensitiveWords': 0.0,
#   'EmbeddedBrandName': 0.0,
#   'PctExtHyperlinks': 0.8333333333,
#   'PctExtResourceUrls': 0.2352941176,
#   'ExtFavicon': 1.0,
#   'InsecureForms': 1.0,
#   'RelativeFormAction': 0.0,
#   'ExtFormAction': 0.0,
#   'AbnormalFormAction': 0.0,
#   'PctNullSelfRedirectHyperlinks': 0.0833333333,
#   'FrequentDomainNameMismatch': 0.0,
#   'FakeLinkInStatusBar': 0.0,
#   'RightClickDisabled': 0.0,
#   'PopUpWindow': 0.0,
#   'SubmitInfoToEmail': 0.0,
#   'IframeOrFrame': 1.0,
#   'MissingTitle': 0.0,
#   'ImagesOnlyInForm': 0.0,
#   'SubdomainLevelRT': 1.0,
#   'UrlLengthRT': 0.0,
#   'PctExtResourceUrlsRT': 1.0,
#   'AbnormalExtFormActionR': 1.0,
#   'ExtMetaScriptLinkRT': 0.0,
#   'PctExtNullSelfRedirectHyperlinksRT': -1.0,
#   'CLASS_LABEL': 1.0},
#  {'NumDots': 1.0,
#   'SubdomainLevel': 0.0,
#   'PathLevel': 10.0,
#   'UrlLength': 105.0,
#   'NumDash': 2.0,
#   'NumDashInHostname': 0.0,
#   'AtSymbol': 0.0,
#   'TildeSymbol': 0.0,
#   'NumUnderscore': 0.0,
#   'NumPercent': 0.0,
#   'NumQueryComponents': 0.0,
#   'NumAmpersand': 0.0,
#   'NumHash': 0.0,
#   'NumNumericChars': 24.0,
#   'NoHttps': 1.0,
#   'RandomString': 1.0,
#   'IpAddress': 0.0,
#   'DomainInSubdomains': 0.0,
#   'DomainInPaths': 1.0,
#   'HttpsInHostname': 0.0,
#   'HostnameLength': 11.0,
#   'PathLength': 87.0,
#   'QueryLength': 0.0,
#   'DoubleSlashInPath': 0.0,
#   'NumSensitiveWords': 0.0,
#   'EmbeddedBrandName': 0.0,
#   'PctExtHyperlinks': 0.0,
#   'PctExtResourceUrls': 0.0,
#   'ExtFavicon': 0.0,
#   'InsecureForms': 1.0,
#   'RelativeFormAction': 0.0,
#   'ExtFormAction': 0.0,
#   'AbnormalFormAction': 0.0,
#   'PctNullSelfRedirectHyperlinks': 0.0,
#   'FrequentDomainNameMismatch': 0.0,
#   'FakeLinkInStatusBar': 0.0,
#   'RightClickDisabled': 0.0,
#   'PopUpWindow': 0.0,
#   'SubmitInfoToEmail': 0.0,
#   'IframeOrFrame': 0.0,
#   'MissingTitle': 0.0,
#   'ImagesOnlyInForm': 0.0,
#   'SubdomainLevelRT': 1.0,
#   'UrlLengthRT': -1.0,
#   'PctExtResourceUrlsRT': 1.0,
#   'AbnormalExtFormActionR': 1.0,
#   'ExtMetaScriptLinkRT': 1.0,
#   'PctExtNullSelfRedirectHyperlinksRT': 1.0,
#   'CLASS_LABEL': 1.0},
#  {'NumDots': 4.0,
#   'SubdomainLevel': 1.0,
#   'PathLevel': 2.0,
#   'UrlLength': 55.0,
#   'NumDash': 0.0,
#   'NumDashInHostname': 0.0,
#   'AtSymbol': 0.0,
#   'TildeSymbol': 0.0,
#   'NumUnderscore': 0.0,
#   'NumPercent': 0.0,
#   'NumQueryComponents': 0.0,
#   'NumAmpersand': 0.0,
#   'NumHash': 0.0,
#   'NumNumericChars': 0.0,
#   'NoHttps': 1.0,
#   'RandomString': 1.0,
#   'IpAddress': 0.0,
#   'DomainInSubdomains': 0.0,
#   'DomainInPaths': 0.0,
#   'HttpsInHostname': 0.0,
#   'HostnameLength': 31.0,
#   'PathLength': 17.0,
#   'QueryLength': 0.0,
#   'DoubleSlashInPath': 0.0,
#   'NumSensitiveWords': 0.0,
#   'EmbeddedBrandName': 0.0,
#   'PctExtHyperlinks': 1.0,
#   'PctExtResourceUrls': 1.0,
#   'ExtFavicon': 0.0,
#   'InsecureForms': 1.0,
#   'RelativeFormAction': 0.0,
#   'ExtFormAction': 0.0,
#   'AbnormalFormAction': 0.0,
#   'PctNullSelfRedirectHyperlinks': 0.0,
#   'FrequentDomainNameMismatch': 1.0,
#   'FakeLinkInStatusBar': 0.0,
#   'RightClickDisabled': 0.0,
#   'PopUpWindow': 0.0,
#   'SubmitInfoToEmail': 0.0,
#   'IframeOrFrame': 0.0,
#   'MissingTitle': 0.0,
#   'ImagesOnlyInForm': 0.0,
#   'SubdomainLevelRT': 1.0,
#   'UrlLengthRT': 0.0,
#   'PctExtResourceUrlsRT': -1.0,
#   'AbnormalExtFormActionR': 1.0,
#   'ExtMetaScriptLinkRT': -1.0,
#   'PctExtNullSelfRedirectHyperlinksRT': -1.0,
#   'CLASS_LABEL': 1.0},
#  {'NumDots': 5.0,
#   'SubdomainLevel': 0.0,
#   'PathLevel': 3.0,
#   'UrlLength': 134.0,
#   'NumDash': 3.0,
#   'NumDashInHostname': 0.0,
#   'AtSymbol': 0.0,
#   'TildeSymbol': 0.0,
#   'NumUnderscore': 0.0,
#   'NumPercent': 0.0,
#   'NumQueryComponents': 0.0,
#   'NumAmpersand': 0.0,
#   'NumHash': 0.0,
#   'NumNumericChars': 1.0,
#   'NoHttps': 1.0,
#   'RandomString': 1.0,
#   'IpAddress': 0.0,
#   'DomainInSubdomains': 0.0,
#   'DomainInPaths': 1.0,
#   'HttpsInHostname': 0.0,
#   'HostnameLength': 14.0,
#   'PathLength': 56.0,
#   'QueryLength': 56.0,
#   'DoubleSlashInPath': 0.0,
#   'NumSensitiveWords': 1.0,
#   'EmbeddedBrandName': 0.0,
#   'PctExtHyperlinks': 0.0,
#   'PctExtResourceUrls': 0.0,
#   'ExtFavicon': 0.0,
#   'InsecureForms': 1.0,
#   'RelativeFormAction': 1.0,
#   'ExtFormAction': 1.0,
#   'AbnormalFormAction': 0.0,
#   'PctNullSelfRedirectHyperlinks': 0.0,
#   'FrequentDomainNameMismatch': 0.0,
#   'FakeLinkInStatusBar': 0.0,
#   'RightClickDisabled': 0.0,
#   'PopUpWindow': 0.0,
#   'SubmitInfoToEmail': 0.0,
#   'IframeOrFrame': 1.0,
#   'MissingTitle': 0.0,
#   'ImagesOnlyInForm': 0.0,
#   'SubdomainLevelRT': 1.0,
#   'UrlLengthRT': -1.0,
#   'PctExtResourceUrlsRT': 1.0,
#   'AbnormalExtFormActionR': 0.0,
#   'ExtMetaScriptLinkRT': 1.0,
#   'PctExtNullSelfRedirectHyperlinksRT': 1.0,
#   'CLASS_LABEL': 1.0},
#  {'NumDots': 2.0,
#   'SubdomainLevel': 0.0,
#   'PathLevel': 3.0,
#   'UrlLength': 43.0,
#   'NumDash': 0.0,
#   'NumDashInHostname': 0.0,
#   'AtSymbol': 0.0,
#   'TildeSymbol': 0.0,
#   'NumUnderscore': 0.0,
#   'NumPercent': 0.0,
#   'NumQueryComponents': 0.0,
#   'NumAmpersand': 0.0,
#   'NumHash': 0.0,
#   'NumNumericChars': 0.0,
#   'NoHttps': 1.0,
#   'RandomString': 0.0,
#   'IpAddress': 0.0,
#   'DomainInSubdomains': 0.0,
#   'DomainInPaths': 1.0,
#   'HttpsInHostname': 0.0,
#   'HostnameLength': 14.0,
#   'PathLength': 22.0,
#   'QueryLength': 0.0,
#   'DoubleSlashInPath': 0.0,
#   'NumSensitiveWords': 0.0,
#   'EmbeddedBrandName': 0.0,
#   'PctExtHyperlinks': 0.0,
#   'PctExtResourceUrls': 0.7857142857,
#   'ExtFavicon': 0.0,
#   'InsecureForms': 1.0,
#   'RelativeFormAction': 0.0,
#   'ExtFormAction': 0.0,
#   'AbnormalFormAction': 0.0,
#   'PctNullSelfRedirectHyperlinks': 1.0,
#   'FrequentDomainNameMismatch': 1.0,
#   'FakeLinkInStatusBar': 0.0,
#   'RightClickDisabled': 0.0,
#   'PopUpWindow': 0.0,
#   'SubmitInfoToEmail': 0.0,
#   'IframeOrFrame': 1.0,
#   'MissingTitle': 0.0,
#   'ImagesOnlyInForm': 0.0,
#   'SubdomainLevelRT': 1.0,
#   'UrlLengthRT': 1.0,
#   'PctExtResourceUrlsRT': -1.0,
#   'AbnormalExtFormActionR': 1.0,
#   'ExtMetaScriptLinkRT': 1.0,
#   'PctExtNullSelfRedirectHyperlinksRT': -1.0,
#   'CLASS_LABEL': 1.0},
#  {'NumDots': 6.0,
#   'SubdomainLevel': 0.0,
#   'PathLevel': 3.0,
#   'UrlLength': 210.0,
#   'NumDash': 2.0,
#   'NumDashInHostname': 0.0,
#   'AtSymbol': 0.0,
#   'TildeSymbol': 0.0,
#   'NumUnderscore': 7.0,
#   'NumPercent': 0.0,
#   'NumQueryComponents': 5.0,
#   'NumAmpersand': 4.0,
#   'NumHash': 0.0,
#   'NumNumericChars': 24.0,
#   'NoHttps': 1.0,
#   'RandomString': 1.0,
#   'IpAddress': 0.0,
#   'DomainInSubdomains': 0.0,
#   'DomainInPaths': 1.0,
#   'HttpsInHostname': 0.0,
#   'HostnameLength': 9.0,
#   'PathLength': 54.0,
#   'QueryLength': 139.0,
#   'DoubleSlashInPath': 0.0,
#   'NumSensitiveWords': 1.0,
#   'EmbeddedBrandName': 0.0,
#   'PctExtHyperlinks': 0.0,
#   'PctExtResourceUrls': 0.9047619048,
#   'ExtFavicon': 0.0,
#   'InsecureForms': 1.0,
#   'RelativeFormAction': 1.0,
#   'ExtFormAction': 0.0,
#   'AbnormalFormAction': 0.0,
#   'PctNullSelfRedirectHyperlinks': 0.0,
#   'FrequentDomainNameMismatch': 0.0,
#   'FakeLinkInStatusBar': 0.0,
#   'RightClickDisabled': 0.0,
#   'PopUpWindow': 0.0,
#   'SubmitInfoToEmail': 0.0,
#   'IframeOrFrame': 0.0,
#   'MissingTitle': 0.0,
#   'ImagesOnlyInForm': 0.0,
#   'SubdomainLevelRT': 1.0,
#   'UrlLengthRT': -1.0,
#   'PctExtResourceUrlsRT': -1.0,
#   'AbnormalExtFormActionR': 1.0,
#   'ExtMetaScriptLinkRT': -1.0,
#   'PctExtNullSelfRedirectHyperlinksRT': 1.0,
#   'CLASS_LABEL': 1.0},
#  {'NumDots': 2.0,
#   'SubdomainLevel': 0.0,
#   'PathLevel': 7.0,
#   'UrlLength': 135.0,
#   'NumDash': 2.0,
#   'NumDashInHostname': 0.0,
#   'AtSymbol': 0.0,
#   'TildeSymbol': 0.0,
#   'NumUnderscore': 3.0,
#   'NumPercent': 0.0,
#   'NumQueryComponents': 2.0,
#   'NumAmpersand': 1.0,
#   'NumHash': 0.0,
#   'NumNumericChars': 1.0,
#   'NoHttps': 1.0,
#   'RandomString': 0.0,
#   'IpAddress': 0.0,
#   'DomainInSubdomains': 0.0,
#   'DomainInPaths': 1.0,
#   'HttpsInHostname': 0.0,
#   'HostnameLength': 22.0,
#   'PathLength': 51.0,
#   'QueryLength': 54.0,
#   'DoubleSlashInPath': 0.0,
#   'NumSensitiveWords': 1.0,
#   'EmbeddedBrandName': 0.0,
#   'PctExtHyperlinks': 0.0,
#   'PctExtResourceUrls': 0.0,
#   'ExtFavicon': 0.0,
#   'InsecureForms': 1.0,
#   'RelativeFormAction': 1.0,
#   'ExtFormAction': 0.0,
#   'AbnormalFormAction': 0.0,
#   'PctNullSelfRedirectHyperlinks': 0.0,
#   'FrequentDomainNameMismatch': 0.0,
#   'FakeLinkInStatusBar': 0.0,
#   'RightClickDisabled': 0.0,
#   'PopUpWindow': 0.0,
#   'SubmitInfoToEmail': 0.0,
#   'IframeOrFrame': 0.0,
#   'MissingTitle': 0.0,
#   'ImagesOnlyInForm': 0.0,
#   'SubdomainLevelRT': 1.0,
#   'UrlLengthRT': -1.0,
#   'PctExtResourceUrlsRT': 1.0,
#   'AbnormalExtFormActionR': 1.0,
#   'ExtMetaScriptLinkRT': 1.0,
#   'PctExtNullSelfRedirectHyperlinksRT': 1.0,
#   'CLASS_LABEL': 1.0},
#  {'NumDots': 5.0,
#   'SubdomainLevel': 0.0,
#   'PathLevel': 6.0,
#   'UrlLength': 85.0,
#   'NumDash': 0.0,
#   'NumDashInHostname': 0.0,
#   'AtSymbol': 0.0,
#   'TildeSymbol': 0.0,
#   'NumUnderscore': 0.0,
#   'NumPercent': 0.0,
#   'NumQueryComponents': 0.0,
#   'NumAmpersand': 0.0,
#   'NumHash': 0.0,
#   'NumNumericChars': 0.0,
#   'NoHttps': 1.0,
#   'RandomString': 1.0,
#   'IpAddress': 0.0,
#   'DomainInSubdomains': 0.0,
#   'DomainInPaths': 1.0,
#   'HttpsInHostname': 0.0,
#   'HostnameLength': 9.0,
#   'PathLength': 69.0,
#   'QueryLength': 0.0,
#   'DoubleSlashInPath': 0.0,
#   'NumSensitiveWords': 0.0,
#   'EmbeddedBrandName': 1.0,
#   'PctExtHyperlinks': 0.6551724138,
#   'PctExtResourceUrls': 0.9285714286,
#   'ExtFavicon': 0.0,
#   'InsecureForms': 1.0,
#   'RelativeFormAction': 1.0,
#   'ExtFormAction': 0.0,
#   'AbnormalFormAction': 1.0,
#   'PctNullSelfRedirectHyperlinks': 0.1034482759,
#   'FrequentDomainNameMismatch': 1.0,
#   'FakeLinkInStatusBar': 0.0,
#   'RightClickDisabled': 0.0,
#   'PopUpWindow': 0.0,
#   'SubmitInfoToEmail': 0.0,
#   'IframeOrFrame': 0.0,
#   'MissingTitle': 0.0,
#   'ImagesOnlyInForm': 0.0,
#   'SubdomainLevelRT': 1.0,
#   'UrlLengthRT': -1.0,
#   'PctExtResourceUrlsRT': -1.0,
#   'AbnormalExtFormActionR': -1.0,
#   'ExtMetaScriptLinkRT': -1.0,
#   'PctExtNullSelfRedirectHyperlinksRT': -1.0,
#   'CLASS_LABEL': 1.0},
#  {'NumDots': 2.0,
#   'SubdomainLevel': 1.0,
#   'PathLevel': 3.0,
#   'UrlLength': 80.0,
#   'NumDash': 0.0,
#   'NumDashInHostname': 0.0,
#   'AtSymbol': 0.0,
#   'TildeSymbol': 0.0,
#   'NumUnderscore': 0.0,
#   'NumPercent': 0.0,
#   'NumQueryComponents': 0.0,
#   'NumAmpersand': 0.0,
#   'NumHash': 0.0,
#   'NumNumericChars': 17.0,
#   'NoHttps': 1.0,
#   'RandomString': 1.0,
#   'IpAddress': 0.0,
#   'DomainInSubdomains': 0.0,
#   'DomainInPaths': 1.0,
#   'HttpsInHostname': 0.0,
#   'HostnameLength': 32.0,
#   'PathLength': 41.0,
#   'QueryLength': 0.0,
#   'DoubleSlashInPath': 0.0,
#   'NumSensitiveWords': 0.0,
#   'EmbeddedBrandName': 0.0,
#   'PctExtHyperlinks': 0.0,
#   'PctExtResourceUrls': 0.0,
#   'ExtFavicon': 0.0,
#   'InsecureForms': 1.0,
#   'RelativeFormAction': 1.0,
#   'ExtFormAction': 0.0,
#   'AbnormalFormAction': 0.0,
#   'PctNullSelfRedirectHyperlinks': 1.0,
#   'FrequentDomainNameMismatch': 0.0,
#   'FakeLinkInStatusBar': 0.0,
#   'RightClickDisabled': 0.0,
#   'PopUpWindow': 0.0,
#   'SubmitInfoToEmail': 0.0,
#   'IframeOrFrame': 0.0,
#   'MissingTitle': 0.0,
#   'ImagesOnlyInForm': 0.0,
#   'SubdomainLevelRT': 1.0,
#   'UrlLengthRT': -1.0,
#   'PctExtResourceUrlsRT': 1.0,
#   'AbnormalExtFormActionR': 1.0,
#   'ExtMetaScriptLinkRT': 1.0,
#   'PctExtNullSelfRedirectHyperlinksRT': -1.0,
#   'CLASS_LABEL': 1.0},
#  {'NumDots': 2.0,
#   'SubdomainLevel': 0.0,
#   'PathLevel': 2.0,
#   'UrlLength': 44.0,
#   'NumDash': 0.0,
#   'NumDashInHostname': 0.0,
#   'AtSymbol': 0.0,
#   'TildeSymbol': 0.0,
#   'NumUnderscore': 0.0,
#   'NumPercent': 0.0,
#   'NumQueryComponents': 0.0,
#   'NumAmpersand': 0.0,
#   'NumHash': 0.0,
#   'NumNumericChars': 4.0,
#   'NoHttps': 1.0,
#   'RandomString': 1.0,
#   'IpAddress': 0.0,
#   'DomainInSubdomains': 0.0,
#   'DomainInPaths': 0.0,
#   'HttpsInHostname': 0.0,
#   'HostnameLength': 19.0,
#   'PathLength': 18.0,
#   'QueryLength': 0.0,
#   'DoubleSlashInPath': 0.0,
#   'NumSensitiveWords': 0.0,
#   'EmbeddedBrandName': 0.0,
#   'PctExtHyperlinks': 1.0,
#   'PctExtResourceUrls': 0.1428571429,
#   'ExtFavicon': 1.0,
#   'InsecureForms': 1.0,
#   'RelativeFormAction': 0.0,
#   'ExtFormAction': 0.0,
#   'AbnormalFormAction': 0.0,
#   'PctNullSelfRedirectHyperlinks': 0.0,
#   'FrequentDomainNameMismatch': 0.0,
#   'FakeLinkInStatusBar': 0.0,
#   'RightClickDisabled': 0.0,
#   'PopUpWindow': 0.0,
#   'SubmitInfoToEmail': 0.0,
#   'IframeOrFrame': 1.0,
#   'MissingTitle': 0.0,
#   'ImagesOnlyInForm': 0.0,
#   'SubdomainLevelRT': 1.0,
#   'UrlLengthRT': 1.0,
#   'PctExtResourceUrlsRT': 1.0,
#   'AbnormalExtFormActionR': 1.0,
#   'ExtMetaScriptLinkRT': 0.0,
#   'PctExtNullSelfRedirectHyperlinksRT': -1.0,
#   'CLASS_LABEL': 1.0},
#  {'NumDots': 3.0,
#   'SubdomainLevel': 0.0,
#   'PathLevel': 9.0,
#   'UrlLength': 95.0,
#   'NumDash': 0.0,
#   'NumDashInHostname': 0.0,
#   'AtSymbol': 0.0,
#   'TildeSymbol': 0.0,
#   'NumUnderscore': 0.0,
#   'NumPercent': 4.0,
#   'NumQueryComponents': 0.0,
#   'NumAmpersand': 0.0,
#   'NumHash': 0.0,
#   'NumNumericChars': 16.0,
#   'NoHttps': 1.0,
#   'RandomString': 1.0,
#   'IpAddress': 0.0,
#   'DomainInSubdomains': 0.0,
#   'DomainInPaths': 0.0,
#   'HttpsInHostname': 0.0,
#   'HostnameLength': 10.0,
#   'PathLength': 78.0,
#   'QueryLength': 0.0,
#   'DoubleSlashInPath': 0.0,
#   'NumSensitiveWords': 0.0,
#   'EmbeddedBrandName': 0.0,
#   'PctExtHyperlinks': 0.0,
#   'PctExtResourceUrls': 0.0,
#   'ExtFavicon': 0.0,
#   'InsecureForms': 1.0,
#   'RelativeFormAction': 0.0,
#   'ExtFormAction': 0.0,
#   'AbnormalFormAction': 0.0,
#   'PctNullSelfRedirectHyperlinks': 1.0,
#   'FrequentDomainNameMismatch': 0.0,
#   'FakeLinkInStatusBar': 0.0,
#   'RightClickDisabled': 0.0,
#   'PopUpWindow': 0.0,
#   'SubmitInfoToEmail': 0.0,
#   'IframeOrFrame': 0.0,
#   'MissingTitle': 0.0,
#   'ImagesOnlyInForm': 1.0,
#   'SubdomainLevelRT': 1.0,
#   'UrlLengthRT': -1.0,
#   'PctExtResourceUrlsRT': 1.0,
#   'AbnormalExtFormActionR': 1.0,
#   'ExtMetaScriptLinkRT': 1.0,
#   'PctExtNullSelfRedirectHyperlinksRT': -1.0,
#   'CLASS_LABEL': 1.0},
#  {'NumDots': 2.0,
#   'SubdomainLevel': 0.0,
#   'PathLevel': 6.0,
#   'UrlLength': 60.0,
#   'NumDash': 1.0,
#   'NumDashInHostname': 0.0,
#   'AtSymbol': 0.0,
#   'TildeSymbol': 0.0,
#   'NumUnderscore': 0.0,
#   'NumPercent': 0.0,
#   'NumQueryComponents': 0.0,
#   'NumAmpersand': 0.0,
#   'NumHash': 0.0,
#   'NumNumericChars': 0.0,
#   'NoHttps': 1.0,
#   'RandomString': 1.0,
#   'IpAddress': 0.0,
#   'DomainInSubdomains': 0.0,
#   'DomainInPaths': 0.0,
#   'HttpsInHostname': 0.0,
#   'HostnameLength': 15.0,
#   'PathLength': 38.0,
#   'QueryLength': 0.0,
#   'DoubleSlashInPath': 0.0,
#   'NumSensitiveWords': 0.0,
#   'EmbeddedBrandName': 0.0,
#   'PctExtHyperlinks': 0.0,
#   'PctExtResourceUrls': 0.0,
#   'ExtFavicon': 0.0,
#   'InsecureForms': 1.0,
#   'RelativeFormAction': 0.0,
#   'ExtFormAction': 0.0,
#   'AbnormalFormAction': 0.0,
#   'PctNullSelfRedirectHyperlinks': 0.0,
#   'FrequentDomainNameMismatch': 0.0,
#   'FakeLinkInStatusBar': 0.0,
#   'RightClickDisabled': 0.0,
#   'PopUpWindow': 0.0,
#   'SubmitInfoToEmail': 0.0,
#   'IframeOrFrame': 0.0,
#   'MissingTitle': 0.0,
#   'ImagesOnlyInForm': 0.0,
#   'SubdomainLevelRT': 1.0,
#   'UrlLengthRT': 0.0,
#   'PctExtResourceUrlsRT': 1.0,
#   'AbnormalExtFormActionR': 1.0,
#   'ExtMetaScriptLinkRT': 1.0,
#   'PctExtNullSelfRedirectHyperlinksRT': 1.0,
#   'CLASS_LABEL': 1.0},
#  {'NumDots': 2.0,
#   'SubdomainLevel': 0.0,
#   'PathLevel': 5.0,
#   'UrlLength': 60.0,
#   'NumDash': 0.0,
#   'NumDashInHostname': 0.0,
#   'AtSymbol': 0.0,
#   'TildeSymbol': 0.0,
#   'NumUnderscore': 0.0,
#   'NumPercent': 0.0,
#   'NumQueryComponents': 0.0,
#   'NumAmpersand': 0.0,
#   'NumHash': 0.0,
#   'NumNumericChars': 0.0,
#   'NoHttps': 1.0,
#   'RandomString': 0.0,
#   'IpAddress': 0.0,
#   'DomainInSubdomains': 0.0,
#   'DomainInPaths': 1.0,
#   'HttpsInHostname': 0.0,
#   'HostnameLength': 12.0,
#   'PathLength': 41.0,
#   'QueryLength': 0.0,
#   'DoubleSlashInPath': 0.0,
#   'NumSensitiveWords': 2.0,
#   'EmbeddedBrandName': 0.0,
#   'PctExtHyperlinks': 0.75,
#   'PctExtResourceUrls': 0.2222222222,
#   'ExtFavicon': 1.0,
#   'InsecureForms': 1.0,
#   'RelativeFormAction': 0.0,
#   'ExtFormAction': 0.0,
#   'AbnormalFormAction': 0.0,
#   'PctNullSelfRedirectHyperlinks': 0.125,
#   'FrequentDomainNameMismatch': 0.0,
#   'FakeLinkInStatusBar': 0.0,
#   'RightClickDisabled': 0.0,
#   'PopUpWindow': 0.0,
#   'SubmitInfoToEmail': 0.0,
#   'IframeOrFrame': 0.0,
#   'MissingTitle': 0.0,
#   'ImagesOnlyInForm': 0.0,
#   'SubdomainLevelRT': 1.0,
#   'UrlLengthRT': 0.0,
#   'PctExtResourceUrlsRT': 1.0,
#   'AbnormalExtFormActionR': 1.0,
#   'ExtMetaScriptLinkRT': 0.0,
#   'PctExtNullSelfRedirectHyperlinksRT': -1.0,
#   'CLASS_LABEL': 1.0},
#  {'NumDots': 6.0,
#   'SubdomainLevel': 0.0,
#   'PathLevel': 2.0,
#   'UrlLength': 100.0,
#   'NumDash': 1.0,
#   'NumDashInHostname': 0.0,
#   'AtSymbol': 0.0,
#   'TildeSymbol': 0.0,
#   'NumUnderscore': 0.0,
#   'NumPercent': 0.0,
#   'NumQueryComponents': 1.0,
#   'NumAmpersand': 0.0,
#   'NumHash': 0.0,
#   'NumNumericChars': 8.0,
#   'NoHttps': 1.0,
#   'RandomString': 0.0,
#   'IpAddress': 0.0,
#   'DomainInSubdomains': 0.0,
#   'DomainInPaths': 0.0,
#   'HttpsInHostname': 0.0,
#   'HostnameLength': 22.0,
#   'PathLength': 18.0,
#   'QueryLength': 52.0,
#   'DoubleSlashInPath': 0.0,
#   'NumSensitiveWords': 1.0,
#   'EmbeddedBrandName': 0.0,
#   'PctExtHyperlinks': 1.0,
#   'PctExtResourceUrls': 1.0,
#   'ExtFavicon': 1.0,
#   'InsecureForms': 1.0,
#   'RelativeFormAction': 0.0,
#   'ExtFormAction': 0.0,
#   'AbnormalFormAction': 0.0,
#   'PctNullSelfRedirectHyperlinks': 0.0,
#   'FrequentDomainNameMismatch': 1.0,
#   'FakeLinkInStatusBar': 0.0,
#   'RightClickDisabled': 0.0,
#   'PopUpWindow': 0.0,
#   'SubmitInfoToEmail': 0.0,
#   'IframeOrFrame': 0.0,
#   'MissingTitle': 0.0,
#   'ImagesOnlyInForm': 0.0,
#   'SubdomainLevelRT': 1.0,
#   'UrlLengthRT': -1.0,
#   'PctExtResourceUrlsRT': -1.0,
#   'AbnormalExtFormActionR': 1.0,
#   'ExtMetaScriptLinkRT': -1.0,
#   'PctExtNullSelfRedirectHyperlinksRT': -1.0,
#   'CLASS_LABEL': 1.0},
#  {'NumDots': 6.0,
#   'SubdomainLevel': 0.0,
#   'PathLevel': 2.0,
#   'UrlLength': 111.0,
#   'NumDash': 1.0,
#   'NumDashInHostname': 0.0,
#   'AtSymbol': 0.0,
#   'TildeSymbol': 0.0,
#   'NumUnderscore': 0.0,
#   'NumPercent': 0.0,
#   'NumQueryComponents': 1.0,
#   'NumAmpersand': 0.0,
#   'NumHash': 1.0,
#   'NumNumericChars': 18.0,
#   'NoHttps': 1.0,
#   'RandomString': 0.0,
#   'IpAddress': 0.0,
#   'DomainInSubdomains': 0.0,
#   'DomainInPaths': 0.0,
#   'HttpsInHostname': 0.0,
#   'HostnameLength': 22.0,
#   'PathLength': 18.0,
#   'QueryLength': 52.0,
#   'DoubleSlashInPath': 0.0,
#   'NumSensitiveWords': 1.0,
#   'EmbeddedBrandName': 0.0,
#   'PctExtHyperlinks': 1.0,
#   'PctExtResourceUrls': 1.0,
#   'ExtFavicon': 1.0,
#   'InsecureForms': 1.0,
#   'RelativeFormAction': 0.0,
#   'ExtFormAction': 0.0,
#   'AbnormalFormAction': 0.0,
#   'PctNullSelfRedirectHyperlinks': 0.0,
#   'FrequentDomainNameMismatch': 1.0,
#   'FakeLinkInStatusBar': 0.0,
#   'RightClickDisabled': 0.0,
#   'PopUpWindow': 0.0,
#   'SubmitInfoToEmail': 0.0,
#   'IframeOrFrame': 0.0,
#   'MissingTitle': 0.0,
#   'ImagesOnlyInForm': 0.0,
#   'SubdomainLevelRT': 1.0,
#   'UrlLengthRT': -1.0,
#   'PctExtResourceUrlsRT': -1.0,
#   'AbnormalExtFormActionR': 1.0,
#   'ExtMetaScriptLinkRT': -1.0,
#   'PctExtNullSelfRedirectHyperlinksRT': -1.0,
#   'CLASS_LABEL': 1.0},
#  {'NumDots': 2.0,
#   'SubdomainLevel': 1.0,
#   'PathLevel': 2.0,
#   'UrlLength': 29.0,
#   'NumDash': 0.0,
#   'NumDashInHostname': 0.0,
#   'AtSymbol': 0.0,
#   'TildeSymbol': 0.0,
#   'NumUnderscore': 0.0,
#   'NumPercent': 0.0,
#   'NumQueryComponents': 0.0,
#   'NumAmpersand': 0.0,
#   'NumHash': 0.0,
#   'NumNumericChars': 0.0,
#   'NoHttps': 1.0,
#   'RandomString': 1.0,
#   'IpAddress': 0.0,
#   'DomainInSubdomains': 0.0,
#   'DomainInPaths': 0.0,
#   'HttpsInHostname': 0.0,
#   'HostnameLength': 16.0,
#   'PathLength': 6.0,
#   'QueryLength': 0.0,
#   'DoubleSlashInPath': 0.0,
#   'NumSensitiveWords': 0.0,
#   'EmbeddedBrandName': 0.0,
#   'PctExtHyperlinks': 0.0,
#   'PctExtResourceUrls': 0.0,
#   'ExtFavicon': 0.0,
#   'InsecureForms': 1.0,
#   'RelativeFormAction': 0.0,
#   'ExtFormAction': 0.0,
#   'AbnormalFormAction': 0.0,
#   'PctNullSelfRedirectHyperlinks': 0.0,
#   'FrequentDomainNameMismatch': 0.0,
#   'FakeLinkInStatusBar': 0.0,
#   'RightClickDisabled': 0.0,
#   'PopUpWindow': 0.0,
#   'SubmitInfoToEmail': 0.0,
#   'IframeOrFrame': 0.0,
#   'MissingTitle': 0.0,
#   'ImagesOnlyInForm': 0.0,
#   'SubdomainLevelRT': 1.0,
#   'UrlLengthRT': 1.0,
#   'PctExtResourceUrlsRT': 1.0,
# ...
#   'PathLength': 14.0,
#   'QueryLength': 0.0,
#   'DoubleSlashInPath': 0.0,
#   'NumSensitiveWords': 0.0,
#   'EmbeddedBrandName': 0.0,
#   'PctExtHyperlinks': 0.0,
#   'PctExtResourceUrls': 0.0625,
#   'ExtFavicon': 0.0,
#   'InsecureForms': 1.0,
#   'RelativeFormAction': 0.0,
#   'ExtFormAction': 0.0,
#   'AbnormalFormAction': 0.0,
#   'PctNullSelfRedirectHyperlinks': 0.0,
#   'FrequentDomainNameMismatch': 0.0,
#   'FakeLinkInStatusBar': 0.0,
#   'RightClickDisabled': 0.0,
#   'PopUpWindow': 0.0,
#   'SubmitInfoToEmail': 0.0,
#   'IframeOrFrame': 1.0,
#   'MissingTitle': 0.0,
#   'ImagesOnlyInForm': 0.0,
#   'SubdomainLevelRT': 1.0,
#   'UrlLengthRT': 1.0,
#   'PctExtResourceUrlsRT': 1.0,
#   'AbnormalExtFormActionR': 1.0,
#   'ExtMetaScriptLinkRT': 0.0,
#   'PctExtNullSelfRedirectHyperlinksRT': 1.0,
#   'CLASS_LABEL': 1.0},
#  {'NumDots': 4.0,
#   'SubdomainLevel': 1.0,
#   'PathLevel': 5.0,
#   'UrlLength': 80.0,
#   'NumDash': 2.0,
#   'NumDashInHostname': 0.0,
#   'AtSymbol': 0.0,
#   'TildeSymbol': 0.0,
#   'NumUnderscore': 0.0,
#   'NumPercent': 0.0,
#   'NumQueryComponents': 0.0,
#   'NumAmpersand': 0.0,
#   'NumHash': 0.0,
#   'NumNumericChars': 0.0,
#   'NoHttps': 1.0,
#   'RandomString': 0.0,
#   'IpAddress': 0.0,
#   'DomainInSubdomains': 0.0,
#   'DomainInPaths': 0.0,
#   'HttpsInHostname': 0.0,
#   'HostnameLength': 26.0,
#   'PathLength': 47.0,
#   'QueryLength': 0.0,
#   'DoubleSlashInPath': 0.0,
#   'NumSensitiveWords': 0.0,
#   'EmbeddedBrandName': 0.0,
#   'PctExtHyperlinks': 0.0,
#   'PctExtResourceUrls': 0.0,
#   'ExtFavicon': 0.0,
#   'InsecureForms': 1.0,
#   'RelativeFormAction': 0.0,
#   'ExtFormAction': 0.0,
#   'AbnormalFormAction': 0.0,
#   'PctNullSelfRedirectHyperlinks': 0.0,
#   'FrequentDomainNameMismatch': 0.0,
#   'FakeLinkInStatusBar': 0.0,
#   'RightClickDisabled': 0.0,
#   'PopUpWindow': 0.0,
#   'SubmitInfoToEmail': 0.0,
#   'IframeOrFrame': 0.0,
#   'MissingTitle': 0.0,
#   'ImagesOnlyInForm': 0.0,
#   'SubdomainLevelRT': 1.0,
#   'UrlLengthRT': -1.0,
#   'PctExtResourceUrlsRT': 1.0,
#   'AbnormalExtFormActionR': 1.0,
#   'ExtMetaScriptLinkRT': 1.0,
#   'PctExtNullSelfRedirectHyperlinksRT': 1.0,
#   'CLASS_LABEL': 1.0},
#  {'NumDots': 3.0,
#   'SubdomainLevel': 1.0,
#   'PathLevel': 8.0,
#   'UrlLength': 78.0,
#   'NumDash': 1.0,
#   'NumDashInHostname': 0.0,
#   'AtSymbol': 0.0,
#   'TildeSymbol': 0.0,
#   'NumUnderscore': 0.0,
#   'NumPercent': 0.0,
#   'NumQueryComponents': 0.0,
#   'NumAmpersand': 0.0,
#   'NumHash': 0.0,
#   'NumNumericChars': 6.0,
#   'NoHttps': 1.0,
#   'RandomString': 1.0,
#   'IpAddress': 0.0,
#   'DomainInSubdomains': 0.0,
#   'DomainInPaths': 1.0,
#   'HttpsInHostname': 0.0,
#   'HostnameLength': 19.0,
#   'PathLength': 52.0,
#   'QueryLength': 0.0,
#   'DoubleSlashInPath': 0.0,
#   'NumSensitiveWords': 0.0,
#   'EmbeddedBrandName': 0.0,
#   'PctExtHyperlinks': 0.9230769231,
#   'PctExtResourceUrls': 1.0,
#   'ExtFavicon': 0.0,
#   'InsecureForms': 1.0,
#   'RelativeFormAction': 0.0,
#   'ExtFormAction': 0.0,
#   'AbnormalFormAction': 0.0,
#   'PctNullSelfRedirectHyperlinks': 0.0,
#   'FrequentDomainNameMismatch': 1.0,
#   'FakeLinkInStatusBar': 0.0,
#   'RightClickDisabled': 0.0,
#   'PopUpWindow': 0.0,
#   'SubmitInfoToEmail': 0.0,
#   'IframeOrFrame': 0.0,
#   'MissingTitle': 0.0,
#   'ImagesOnlyInForm': 0.0,
#   'SubdomainLevelRT': 1.0,
#   'UrlLengthRT': -1.0,
#   'PctExtResourceUrlsRT': 1.0,
#   'AbnormalExtFormActionR': 1.0,
#   'ExtMetaScriptLinkRT': -1.0,
#   'PctExtNullSelfRedirectHyperlinksRT': -1.0,
#   'CLASS_LABEL': 1.0},
#  {'NumDots': 2.0,
#   'SubdomainLevel': 0.0,
#   'PathLevel': 2.0,
#   'UrlLength': 39.0,
#   'NumDash': 0.0,
#   'NumDashInHostname': 0.0,
#   'AtSymbol': 0.0,
#   'TildeSymbol': 0.0,
#   'NumUnderscore': 0.0,
#   'NumPercent': 0.0,
#   'NumQueryComponents': 0.0,
#   'NumAmpersand': 0.0,
#   'NumHash': 0.0,
#   'NumNumericChars': 0.0,
#   'NoHttps': 1.0,
#   'RandomString': 1.0,
#   'IpAddress': 0.0,
#   'DomainInSubdomains': 0.0,
#   'DomainInPaths': 0.0,
#   'HttpsInHostname': 0.0,
#   'HostnameLength': 16.0,
#   'PathLength': 16.0,
#   'QueryLength': 0.0,
#   'DoubleSlashInPath': 0.0,
#   'NumSensitiveWords': 0.0,
#   'EmbeddedBrandName': 0.0,
#   'PctExtHyperlinks': 0.9230769231,
#   'PctExtResourceUrls': 1.0,
#   'ExtFavicon': 0.0,
#   'InsecureForms': 1.0,
#   'RelativeFormAction': 0.0,
#   'ExtFormAction': 0.0,
#   'AbnormalFormAction': 0.0,
#   'PctNullSelfRedirectHyperlinks': 0.0,
#   'FrequentDomainNameMismatch': 1.0,
#   'FakeLinkInStatusBar': 0.0,
#   'RightClickDisabled': 0.0,
#   'PopUpWindow': 0.0,
#   'SubmitInfoToEmail': 0.0,
#   'IframeOrFrame': 0.0,
#   'MissingTitle': 0.0,
#   'ImagesOnlyInForm': 0.0,
#   'SubdomainLevelRT': 1.0,
#   'UrlLengthRT': 1.0,
#   'PctExtResourceUrlsRT': 1.0,
#   'AbnormalExtFormActionR': 1.0,
#   'ExtMetaScriptLinkRT': -1.0,
#   'PctExtNullSelfRedirectHyperlinksRT': -1.0,
#   'CLASS_LABEL': 1.0},
#  {'NumDots': 3.0,
#   'SubdomainLevel': 0.0,
#   'PathLevel': 3.0,
#   'UrlLength': 40.0,
#   'NumDash': 0.0,
#   'NumDashInHostname': 0.0,
#   'AtSymbol': 0.0,
#   'TildeSymbol': 1.0,
#   'NumUnderscore': 0.0,
#   'NumPercent': 0.0,
#   'NumQueryComponents': 0.0,
#   'NumAmpersand': 0.0,
#   'NumHash': 0.0,
#   'NumNumericChars': 13.0,
#   'NoHttps': 1.0,
#   'RandomString': 1.0,
#   'IpAddress': 1.0,
#   'DomainInSubdomains': 0.0,
#   'DomainInPaths': 0.0,
#   'HttpsInHostname': 0.0,
#   'HostnameLength': 13.0,
#   'PathLength': 20.0,
#   'QueryLength': 0.0,
#   'DoubleSlashInPath': 0.0,
#   'NumSensitiveWords': 0.0,
#   'EmbeddedBrandName': 0.0,
#   'PctExtHyperlinks': 1.0,
#   'PctExtResourceUrls': 0.1428571429,
#   'ExtFavicon': 0.0,
#   'InsecureForms': 1.0,
#   'RelativeFormAction': 0.0,
#   'ExtFormAction': 0.0,
#   'AbnormalFormAction': 0.0,
#   'PctNullSelfRedirectHyperlinks': 0.0,
#   'FrequentDomainNameMismatch': 1.0,
#   'FakeLinkInStatusBar': 0.0,
#   'RightClickDisabled': 0.0,
#   'PopUpWindow': 0.0,
#   'SubmitInfoToEmail': 0.0,
#   'IframeOrFrame': 1.0,
#   'MissingTitle': 0.0,
#   'ImagesOnlyInForm': 0.0,
#   'SubdomainLevelRT': 1.0,
#   'UrlLengthRT': 1.0,
#   'PctExtResourceUrlsRT': 1.0,
#   'AbnormalExtFormActionR': 1.0,
#   'ExtMetaScriptLinkRT': 1.0,
#   'PctExtNullSelfRedirectHyperlinksRT': -1.0,
#   'CLASS_LABEL': 1.0},
#  {'NumDots': 3.0,
#   'SubdomainLevel': 0.0,
#   'PathLevel': 3.0,
#   'UrlLength': 40.0,
#   'NumDash': 0.0,
#   'NumDashInHostname': 0.0,
#   'AtSymbol': 0.0,
#   'TildeSymbol': 1.0,
#   'NumUnderscore': 0.0,
#   'NumPercent': 0.0,
#   'NumQueryComponents': 0.0,
#   'NumAmpersand': 0.0,
#   'NumHash': 0.0,
#   'NumNumericChars': 13.0,
#   'NoHttps': 1.0,
#   'RandomString': 1.0,
#   'IpAddress': 1.0,
#   'DomainInSubdomains': 0.0,
#   'DomainInPaths': 0.0,
#   'HttpsInHostname': 0.0,
#   'HostnameLength': 13.0,
#   'PathLength': 20.0,
#   'QueryLength': 0.0,
#   'DoubleSlashInPath': 0.0,
#   'NumSensitiveWords': 0.0,
#   'EmbeddedBrandName': 0.0,
#   'PctExtHyperlinks': 1.0,
#   'PctExtResourceUrls': 0.1428571429,
#   'ExtFavicon': 0.0,
#   'InsecureForms': 1.0,
#   'RelativeFormAction': 0.0,
#   'ExtFormAction': 0.0,
#   'AbnormalFormAction': 0.0,
#   'PctNullSelfRedirectHyperlinks': 0.0,
#   'FrequentDomainNameMismatch': 1.0,
#   'FakeLinkInStatusBar': 0.0,
#   'RightClickDisabled': 0.0,
#   'PopUpWindow': 0.0,
#   'SubmitInfoToEmail': 0.0,
#   'IframeOrFrame': 1.0,
#   'MissingTitle': 0.0,
#   'ImagesOnlyInForm': 0.0,
#   'SubdomainLevelRT': 1.0,
#   'UrlLengthRT': 1.0,
#   'PctExtResourceUrlsRT': 1.0,
#   'AbnormalExtFormActionR': 1.0,
#   'ExtMetaScriptLinkRT': 1.0,
#   'PctExtNullSelfRedirectHyperlinksRT': -1.0,
#   'CLASS_LABEL': 1.0},
#  {'NumDots': 2.0,
#   'SubdomainLevel': 0.0,
#   'PathLevel': 3.0,
#   'UrlLength': 42.0,
#   'NumDash': 1.0,
#   'NumDashInHostname': 0.0,
#   'AtSymbol': 0.0,
#   'TildeSymbol': 0.0,
#   'NumUnderscore': 0.0,
#   'NumPercent': 0.0,
#   'NumQueryComponents': 0.0,
#   'NumAmpersand': 0.0,
#   'NumHash': 0.0,
#   'NumNumericChars': 0.0,
#   'NoHttps': 1.0,
#   'RandomString': 0.0,
#   'IpAddress': 0.0,
#   'DomainInSubdomains': 0.0,
#   'DomainInPaths': 1.0,
#   'HttpsInHostname': 0.0,
#   'HostnameLength': 17.0,
#   'PathLength': 18.0,
#   'QueryLength': 0.0,
#   'DoubleSlashInPath': 0.0,
#   'NumSensitiveWords': 0.0,
#   'EmbeddedBrandName': 0.0,
#   'PctExtHyperlinks': 0.0,
#   'PctExtResourceUrls': 0.75,
#   'ExtFavicon': 0.0,
#   'InsecureForms': 1.0,
#   'RelativeFormAction': 0.0,
#   'ExtFormAction': 0.0,
#   'AbnormalFormAction': 0.0,
#   'PctNullSelfRedirectHyperlinks': 0.0,
#   'FrequentDomainNameMismatch': 1.0,
#   'FakeLinkInStatusBar': 0.0,
#   'RightClickDisabled': 0.0,
#   'PopUpWindow': 0.0,
#   'SubmitInfoToEmail': 0.0,
#   'IframeOrFrame': 0.0,
#   'MissingTitle': 0.0,
#   'ImagesOnlyInForm': 0.0,
#   'SubdomainLevelRT': 1.0,
#   'UrlLengthRT': 1.0,
#   'PctExtResourceUrlsRT': 0.0,
#   'AbnormalExtFormActionR': 1.0,
#   'ExtMetaScriptLinkRT': -1.0,
#   'PctExtNullSelfRedirectHyperlinksRT': 1.0,
#   'CLASS_LABEL': 1.0},
#  {'NumDots': 2.0,
#   'SubdomainLevel': 0.0,
#   'PathLevel': 5.0,
#   'UrlLength': 88.0,
#   'NumDash': 0.0,
#   'NumDashInHostname': 0.0,
#   'AtSymbol': 0.0,
#   'TildeSymbol': 0.0,
#   'NumUnderscore': 0.0,
#   'NumPercent': 0.0,
#   'NumQueryComponents': 0.0,
#   'NumAmpersand': 0.0,
#   'NumHash': 0.0,
#   'NumNumericChars': 0.0,
#   'NoHttps': 1.0,
#   'RandomString': 0.0,
#   'IpAddress': 0.0,
#   'DomainInSubdomains': 0.0,
#   'DomainInPaths': 0.0,
#   'HttpsInHostname': 0.0,
#   'HostnameLength': 25.0,
#   'PathLength': 56.0,
#   'QueryLength': 0.0,
#   'DoubleSlashInPath': 0.0,
#   'NumSensitiveWords': 0.0,
#   'EmbeddedBrandName': 0.0,
#   'PctExtHyperlinks': 0.5,
#   'PctExtResourceUrls': 0.0172413793,
#   'ExtFavicon': 0.0,
#   'InsecureForms': 1.0,
#   'RelativeFormAction': 0.0,
#   'ExtFormAction': 0.0,
#   'AbnormalFormAction': 0.0,
#   'PctNullSelfRedirectHyperlinks': 0.5,
#   'FrequentDomainNameMismatch': 0.0,
#   'FakeLinkInStatusBar': 0.0,
#   'RightClickDisabled': 0.0,
#   'PopUpWindow': 0.0,
#   'SubmitInfoToEmail': 0.0,
#   'IframeOrFrame': 0.0,
#   'MissingTitle': 0.0,
#   'ImagesOnlyInForm': 0.0,
#   'SubdomainLevelRT': 1.0,
#   'UrlLengthRT': -1.0,
#   'PctExtResourceUrlsRT': 1.0,
#   'AbnormalExtFormActionR': 1.0,
#   'ExtMetaScriptLinkRT': 1.0,
#   'PctExtNullSelfRedirectHyperlinksRT': -1.0,
#   'CLASS_LABEL': 1.0},
#  {'NumDots': 2.0,
#   'SubdomainLevel': 0.0,
#   'PathLevel': 7.0,
#   'UrlLength': 125.0,
#   'NumDash': 0.0,
#   'NumDashInHostname': 0.0,
#   'AtSymbol': 0.0,
#   'TildeSymbol': 0.0,
#   'NumUnderscore': 0.0,
#   'NumPercent': 0.0,
#   'NumQueryComponents': 0.0,
#   'NumAmpersand': 0.0,
#   'NumHash': 0.0,
#   'NumNumericChars': 42.0,
#   'NoHttps': 1.0,
#   'RandomString': 1.0,
#   'IpAddress': 0.0,
#   'DomainInSubdomains': 0.0,
#   'DomainInPaths': 0.0,
#   'HttpsInHostname': 0.0,
#   'HostnameLength': 15.0,
#   'PathLength': 103.0,
#   'QueryLength': 0.0,
#   'DoubleSlashInPath': 0.0,
#   'NumSensitiveWords': 0.0,
#   'EmbeddedBrandName': 0.0,
#   'PctExtHyperlinks': 0.0,
#   'PctExtResourceUrls': 1.0,
#   'ExtFavicon': 0.0,
#   'InsecureForms': 1.0,
#   'RelativeFormAction': 1.0,
#   'ExtFormAction': 0.0,
#   'AbnormalFormAction': 0.0,
#   'PctNullSelfRedirectHyperlinks': 1.0,
#   'FrequentDomainNameMismatch': 1.0,
#   'FakeLinkInStatusBar': 0.0,
#   'RightClickDisabled': 0.0,
#   'PopUpWindow': 0.0,
#   'SubmitInfoToEmail': 0.0,
#   'IframeOrFrame': 0.0,
#   'MissingTitle': 0.0,
#   'ImagesOnlyInForm': 0.0,
#   'SubdomainLevelRT': 1.0,
#   'UrlLengthRT': -1.0,
#   'PctExtResourceUrlsRT': -1.0,
#   'AbnormalExtFormActionR': 1.0,
#   'ExtMetaScriptLinkRT': -1.0,
#   'PctExtNullSelfRedirectHyperlinksRT': -1.0,
#   'CLASS_LABEL': 1.0},
#  {'NumDots': 3.0,
#   'SubdomainLevel': 1.0,
#   'PathLevel': 3.0,
#   'UrlLength': 53.0,
#   'NumDash': 0.0,
#   'NumDashInHostname': 0.0,
#   'AtSymbol': 0.0,
#   'TildeSymbol': 0.0,
#   'NumUnderscore': 0.0,
#   'NumPercent': 0.0,
#   'NumQueryComponents': 0.0,
#   'NumAmpersand': 0.0,
#   'NumHash': 0.0,
#   'NumNumericChars': 0.0,
#   'NoHttps': 1.0,
#   'RandomString': 0.0,
#   'IpAddress': 0.0,
#   'DomainInSubdomains': 0.0,
#   'DomainInPaths': 0.0,
#   'HttpsInHostname': 0.0,
#   'HostnameLength': 21.0,
#   'PathLength': 25.0,
#   'QueryLength': 0.0,
#   'DoubleSlashInPath': 0.0,
#   'NumSensitiveWords': 0.0,
#   'EmbeddedBrandName': 0.0,
#   'PctExtHyperlinks': 0.0,
#   'PctExtResourceUrls': 0.0,
#   'ExtFavicon': 0.0,
#   'InsecureForms': 1.0,
#   'RelativeFormAction': 0.0,
#   'ExtFormAction': 0.0,
#   'AbnormalFormAction': 0.0,
#   'PctNullSelfRedirectHyperlinks': 0.0,
#   'FrequentDomainNameMismatch': 0.0,
#   'FakeLinkInStatusBar': 0.0,
#   'RightClickDisabled': 0.0,
#   'PopUpWindow': 0.0,
#   'SubmitInfoToEmail': 0.0,
#   'IframeOrFrame': 0.0,
#   'MissingTitle': 0.0,
#   'ImagesOnlyInForm': 0.0,
#   'SubdomainLevelRT': 1.0,
#   'UrlLengthRT': 1.0,
#   'PctExtResourceUrlsRT': 1.0,
#   'AbnormalExtFormActionR': 1.0,
#   'ExtMetaScriptLinkRT': 1.0,
#   'PctExtNullSelfRedirectHyperlinksRT': 1.0,
#   'CLASS_LABEL': 1.0},
#  {'NumDots': 4.0,
#   'SubdomainLevel': 0.0,
#   'PathLevel': 5.0,
#   'UrlLength': 114.0,
#   'NumDash': 1.0,
#   'NumDashInHostname': 0.0,
#   'AtSymbol': 0.0,
#   'TildeSymbol': 0.0,
#   'NumUnderscore': 3.0,
#   'NumPercent': 0.0,
#   'NumQueryComponents': 1.0,
#   'NumAmpersand': 1.0,
#   'NumHash': 0.0,
#   'NumNumericChars': 11.0,
#   'NoHttps': 1.0,
#   'RandomString': 1.0,
#   'IpAddress': 1.0,
#   'DomainInSubdomains': 0.0,
#   'DomainInPaths': 1.0,
#   'HttpsInHostname': 0.0,
#   'HostnameLength': 13.0,
#   'PathLength': 46.0,
#   'QueryLength': 47.0,
#   'DoubleSlashInPath': 0.0,
#   'NumSensitiveWords': 0.0,
#   'EmbeddedBrandName': 0.0,
#   'PctExtHyperlinks': 0.0,
#   'PctExtResourceUrls': 0.0,
#   'ExtFavicon': 0.0,
#   'InsecureForms': 1.0,
#   'RelativeFormAction': 1.0,
#   'ExtFormAction': 0.0,
#   'AbnormalFormAction': 0.0,
#   'PctNullSelfRedirectHyperlinks': 0.0,
#   'FrequentDomainNameMismatch': 1.0,
#   'FakeLinkInStatusBar': 0.0,
#   'RightClickDisabled': 0.0,
#   'PopUpWindow': 0.0,
#   'SubmitInfoToEmail': 0.0,
#   'IframeOrFrame': 0.0,
#   'MissingTitle': 0.0,
#   'ImagesOnlyInForm': 0.0,
#   'SubdomainLevelRT': 1.0,
#   'UrlLengthRT': -1.0,
#   'PctExtResourceUrlsRT': 1.0,
#   'AbnormalExtFormActionR': 1.0,
#   'ExtMetaScriptLinkRT': 1.0,
#   'PctExtNullSelfRedirectHyperlinksRT': 1.0,
#   'CLASS_LABEL': 1.0},
#  {'NumDots': 4.0,
#   'SubdomainLevel': 0.0,
#   'PathLevel': 5.0,
#   'UrlLength': 66.0,
#   'NumDash': 0.0,
#   'NumDashInHostname': 0.0,
#   'AtSymbol': 0.0,
#   'TildeSymbol': 0.0,
#   'NumUnderscore': 0.0,
#   'NumPercent': 0.0,
#   'NumQueryComponents': 0.0,
#   'NumAmpersand': 0.0,
#   'NumHash': 0.0,
#   'NumNumericChars': 10.0,
#   'NoHttps': 1.0,
#   'RandomString': 1.0,
#   'IpAddress': 1.0,
#   'DomainInSubdomains': 0.0,
#   'DomainInPaths': 1.0,
#   'HttpsInHostname': 0.0,
#   'HostnameLength': 13.0,
#   'PathLength': 46.0,
#   'QueryLength': 0.0,
#   'DoubleSlashInPath': 0.0,
#   'NumSensitiveWords': 0.0,
#   'EmbeddedBrandName': 0.0,
#   'PctExtHyperlinks': 0.0,
#   'PctExtResourceUrls': 0.0,
#   'ExtFavicon': 0.0,
#   'InsecureForms': 1.0,
#   'RelativeFormAction': 1.0,
#   'ExtFormAction': 0.0,
#   'AbnormalFormAction': 0.0,
#   'PctNullSelfRedirectHyperlinks': 0.0,
#   'FrequentDomainNameMismatch': 1.0,
#   'FakeLinkInStatusBar': 0.0,
#   'RightClickDisabled': 0.0,
#   'PopUpWindow': 0.0,
#   'SubmitInfoToEmail': 0.0,
#   'IframeOrFrame': 0.0,
#   'MissingTitle': 0.0,
#   'ImagesOnlyInForm': 0.0,
#   'SubdomainLevelRT': 1.0,
#   'UrlLengthRT': 0.0,
#   'PctExtResourceUrlsRT': 1.0,
#   'AbnormalExtFormActionR': 1.0,
#   'ExtMetaScriptLinkRT': 1.0,
#   'PctExtNullSelfRedirectHyperlinksRT': 1.0,
#   'CLASS_LABEL': 1.0},
#  {'NumDots': 2.0,
#   'SubdomainLevel': 0.0,
#   'PathLevel': 2.0,
#   'UrlLength': 36.0,
#   'NumDash': 0.0,
#   'NumDashInHostname': 0.0,
#   'AtSymbol': 0.0,
#   'TildeSymbol': 0.0,
#   'NumUnderscore': 0.0,
#   'NumPercent': 0.0,
#   'NumQueryComponents': 0.0,
#   'NumAmpersand': 0.0,
#   'NumHash': 0.0,
#   'NumNumericChars': 4.0,
#   'NoHttps': 1.0,
#   'RandomString': 1.0,
#   'IpAddress': 0.0,
#   'DomainInSubdomains': 0.0,
#   'DomainInPaths': 0.0,
#   'HttpsInHostname': 0.0,
#   'HostnameLength': 13.0,
#   'PathLength': 16.0,
#   'QueryLength': 0.0,
#   'DoubleSlashInPath': 0.0,
#   'NumSensitiveWords': 0.0,
#   'EmbeddedBrandName': 0.0,
#   'PctExtHyperlinks': 0.0,
#   'PctExtResourceUrls': 0.0,
#   'ExtFavicon': 0.0,
#   'InsecureForms': 1.0,
#   'RelativeFormAction': 0.0,
#   'ExtFormAction': 0.0,
#   'AbnormalFormAction': 0.0,
#   'PctNullSelfRedirectHyperlinks': 0.0,
#   'FrequentDomainNameMismatch': 0.0,
#   'FakeLinkInStatusBar': 0.0,
#   'RightClickDisabled': 0.0,
#   'PopUpWindow': 0.0,
#   'SubmitInfoToEmail': 0.0,
#   'IframeOrFrame': 0.0,
#   'MissingTitle': 0.0,
#   'ImagesOnlyInForm': 0.0,
#   'SubdomainLevelRT': 1.0,
#   'UrlLengthRT': 1.0,
#   'PctExtResourceUrlsRT': 1.0,
#   'AbnormalExtFormActionR': 1.0,
#   'ExtMetaScriptLinkRT': 1.0,
#   'PctExtNullSelfRedirectHyperlinksRT': 1.0,
#   'CLASS_LABEL': 1.0},
#  ...]
